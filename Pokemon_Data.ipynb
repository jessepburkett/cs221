# %%
import numpy as np
import pandas as pd
import ast

moves = pd.read_csv('move-data.csv', index_col = 0)

## convert csv vals for Move power and accuracy to floats (or nan)
for var in ['Power', 'Accuracy']:
    moves[var].replace('None', np.nan, inplace=True)
    moves[var] = moves[var].astype(float)

moves.head()
# Out:
#               Name      Type  Category Contest  PP  Power  Accuracy  \
# Index
# 1            Pound    Normal  Physical   Tough  35   40.0     100.0
# 2      Karate Chop  Fighting  Physical   Tough  25   50.0     100.0
# 3      Double Slap    Normal  Physical    Cute  10   15.0      85.0
# 4      Comet Punch    Normal  Physical   Tough  15   18.0      85.0
# 5       Mega Punch    Normal  Physical   Tough  20   80.0      85.0
#
#        Generation
# Index
# 1               1
# 2               1
# 3               1
# 4               1
# 5               1

# %%
pokemon = pd.read_csv('pokemon-data.csv', sep = ';', converters={'Types':ast.literal_eval, 'Abilities':ast.literal_eval, 'Moves':ast.literal_eval})

pokemon.head()
# Out:
#              Name         Types                                Abilities  \
# 0       Abomasnow  [Grass, Ice]               [Snow Warning, Soundproof]
# 1  Abomasnow-Mega  [Grass, Ice]                           [Snow Warning]
# 2            Abra     [Psychic]  [Inner Focus, Magic Guard, Synchronize]
# 3           Absol        [Dark]        [Justified, Pressure, Super Luck]
# 4      Absol-Mega        [Dark]                           [Magic Bounce]
#
#    Tier  HP  Attack  Defense  Special Attack  Special Defense  Speed  \
# 0    PU  90      92       75              92               85     60
# 1  NUBL  90     132      105             132              105     30
# 2    LC  25      20       15             105               55     90
# 3    PU  65     130       60              75               60     75
# 4  RUBL  65     150       60             115               60    115
#
#   Next Evolution(s)                                              Moves
# 0                []  [Ice Punch, Powder Snow, Leer, Razor Leaf, Icy...
# 1                []  [Ice Punch, Powder Snow, Leer, Razor Leaf, Icy...
# 2       ['Kadabra']  [Teleport, Ally Switch, Barrier, Encore, Fire ...
# 3                []  [Perish Song, Future Sight, Me First, Razor Wi...
# 4                []  [Perish Song, Future Sight, Me First, Razor Wi...

# %%
## convert from data frame to dict of move-->(type, category, pp, power, accuracy)
movesDict = moves.to_dict()
nameDict = {}
for key in movesDict['Name']:
    nameDict[movesDict['Name'][key]] = [movesDict['Type'][key], movesDict['Category'][key], movesDict['PP'][key], movesDict['Power'][key], movesDict['Accuracy'][key]]

nameDict
# Out:
# {'Pound': ['Normal', 'Physical', 35, 40.0, 100.0],
#  'Karate Chop': ['Fighting', 'Physical', 25, 50.0, 100.0],
#  'Double Slap': ['Normal', 'Physical', 10, 15.0, 85.0],
#  'Comet Punch': ['Normal', 'Physical', 15, 18.0, 85.0],
#  'Mega Punch': ['Normal', 'Physical', 20, 80.0, 85.0],
#  'Pay Day': ['Normal', 'Physical', 20, 40.0, 100.0],
#  'Fire Punch': ['Fire', 'Physical', 15, 75.0, 100.0],
#  'Ice Punch': ['Ice', 'Physical', 15, 75.0, 100.0],
#  'Thunder Punch': ['Electric', 'Physical', 15, 75.0, 100.0],
#  'Scratch': ['Normal', 'Physical', 35, 40.0, 100.0],
#  'Vice Grip': ['Normal', 'Physical', 30, 55.0, 100.0],
#  'Guillotine': ['Normal', 'Physical', 5, nan, nan],
#  'Razor Wind': ['Normal', 'Special', 10, 80.0, nan],
#  'Swords Dance': ['Normal', 'Status', 20, nan, nan],
#  'Cut': ['Normal', 'Physical', 30, 50.0, 95.0],
#  'Gust': ['Flying', 'Special', 35, 40.0, 100.0],
#  'Wing Attack': ['Flying', 'Physical', 35, 60.0, 100.0],
#  'Whirlwind': ['Normal', 'Status', 20, nan, nan],
#  'Fly': ['Flying', 'Physical', 15, 90.0, 95.0],
#  'Bind': ['Normal', 'Physical', 20, 15.0, nan],
#  'Slam': ['Normal', 'Physical', 20, 80.0, 75.0],
#  'Vine Whip': ['Grass', 'Physical', 25, 45.0, 100.0],
#  'Stomp': ['Normal', 'Physical', 20, 65.0, 100.0],
#  'Double Kick': ['Fighting', 'Physical', 30, 30.0, 100.0],
#  'Mega Kick': ['Normal', 'Physical', 5, 120.0, 75.0],
#  'Jump Kick': ['Fighting', 'Physical', 10, 100.0, 95.0],
#  'Rolling Kick': ['Fighting', 'Physical', 15, 60.0, 85.0],
#  'Sand Attack': ['Ground', 'Status', 15, nan, 100.0],
#  'Headbutt': ['Normal', 'Physical', 15, 70.0, 100.0],
#  'Horn Attack': ['Normal', 'Physical', 25, 65.0, 100.0],
#  'Fury Attack': ['Normal', 'Physical', 20, 15.0, 85.0],
#  'Horn Drill': ['Normal', 'Physical', 5, nan, nan],
#  'Tackle': ['Normal', 'Physical', 35, 40.0, nan],
#  'Body Slam': ['Normal', 'Physical', 15, 85.0, 100.0],
#  'Wrap': ['Normal', 'Physical', 20, 15.0, nan],
#  'Take Down': ['Normal', 'Physical', 20, 90.0, 85.0],
#  'Thrash': ['Normal', 'Physical', 10, 120.0, 100.0],
#  'Double-Edge': ['Normal', 'Physical', 15, 120.0, 100.0],
#  'Tail Whip': ['Normal', 'Status', 30, nan, 100.0],
#  'Poison Sting': ['Poison', 'Physical', 35, 15.0, 100.0],
#  'Twineedle': ['Bug', 'Physical', 20, 25.0, 100.0],
#  'Pin Missile': ['Bug', 'Physical', 20, 25.0, nan],
#  'Leer': ['Normal', 'Status', 30, nan, 100.0],
#  'Bite': ['Dark', 'Physical', 25, 60.0, 100.0],
#  'Growl': ['Normal', 'Status', 40, nan, 100.0],
#  'Roar': ['Normal', 'Status', 20, nan, nan],
#  'Sing': ['Normal', 'Status', 15, nan, 55.0],
#  'Supersonic': ['Normal', 'Status', 20, nan, 55.0],
#  'Sonic Boom': ['Normal', 'Special', 20, nan, 90.0],
#  'Disable': ['Normal', 'Status', 20, nan, nan],
#  'Acid': ['Poison', 'Special', 30, 40.0, 100.0],
#  'Ember': ['Fire', 'Special', 25, 40.0, 100.0],
#  'Flamethrower': ['Fire', 'Special', 15, 90.0, 100.0],
#  'Mist': ['Ice', 'Status', 30, nan, nan],
#  'Water Gun': ['Water', 'Special', 25, 40.0, 100.0],
#  'Hydro Pump': ['Water', 'Special', 5, 110.0, 80.0],
#  'Surf': ['Water', 'Special', 15, 90.0, 100.0],
#  'Ice Beam': ['Ice', 'Special', 10, 90.0, 100.0],
#  'Blizzard': ['Ice', 'Special', 5, 110.0, nan],
#  'Psybeam': ['Psychic', 'Special', 20, 65.0, 100.0],
#  'Bubble Beam': ['Water', 'Special', 20, 65.0, 100.0],
#  'Aurora Beam': ['Ice', 'Special', 20, 65.0, 100.0],
#  'Hyper Beam': ['Normal', 'Special', 5, 150.0, 90.0],
#  'Peck': ['Flying', 'Physical', 35, 35.0, 100.0],
#  'Drill Peck': ['Flying', 'Physical', 20, 80.0, 100.0],
#  'Submission': ['Fighting', 'Physical', 20, 80.0, 80.0],
#  'Low Kick': ['Fighting', 'Physical', 20, nan, nan],
#  'Counter': ['Fighting', 'Physical', 20, nan, 100.0],
#  'Seismic Toss': ['Fighting', 'Physical', 20, nan, 100.0],
#  'Strength': ['Normal', 'Physical', 15, 80.0, 100.0],
#  'Absorb': ['Grass', 'Special', 25, 20.0, 100.0],
#  'Mega Drain': ['Grass', 'Special', 15, 40.0, 100.0],
#  'Leech Seed': ['Grass', 'Status', 10, nan, 90.0],
#  'Growth': ['Normal', 'Status', 20, nan, nan],
#  'Razor Leaf': ['Grass', 'Physical', 25, 55.0, 95.0],
#  'Solar Beam': ['Grass', 'Special', 10, 120.0, 100.0],
#  'Poison Powder': ['Poison', 'Status', 35, nan, 75.0],
#  'Stun Spore': ['Grass', 'Status', 30, nan, 75.0],
#  'Sleep Powder': ['Grass', 'Status', 15, nan, 75.0],
#  'Petal Dance': ['Grass', 'Special', 10, 120.0, 100.0],
#  'String Shot': ['Bug', 'Status', 40, nan, 95.0],
#  'Dragon Rage': ['Dragon', 'Special', 10, nan, 100.0],
#  'Fire Spin': ['Fire', 'Special', 15, 35.0, nan],
#  'Thunder Shock': ['Electric', 'Special', 30, 40.0, 100.0],
#  'Thunderbolt': ['Electric', 'Special', 15, 90.0, 100.0],
#  'Thunder Wave': ['Electric', 'Status', 20, nan, nan],
#  'Thunder': ['Electric', 'Special', 10, 110.0, 70.0],
#  'Rock Throw': ['Rock', 'Physical', 15, 50.0, nan],
#  'Earthquake': ['Ground', 'Physical', 10, 100.0, 100.0],
#  'Fissure': ['Ground', 'Physical', 5, nan, nan],
#  'Dig': ['Ground', 'Physical', 10, 80.0, 100.0],
#  'Toxic': ['Poison', 'Status', 10, nan, nan],
#  'Confusion': ['Psychic', 'Special', 25, 50.0, 100.0],
#  'Psychic': ['Psychic', 'Special', 10, 90.0, 100.0],
#  'Hypnosis': ['Psychic', 'Status', 20, nan, nan],
#  'Meditate': ['Psychic', 'Status', 40, nan, nan],
#  'Agility': ['Psychic', 'Status', 30, nan, nan],
#  'Quick Attack': ['Normal', 'Physical', 30, 40.0, 100.0],
#  'Rage': ['Normal', 'Physical', 20, 20.0, 100.0],
#  'Teleport': ['Psychic', 'Status', 20, nan, nan],
#  'Night Shade': ['Ghost', 'Special', 15, nan, 100.0],
#  'Mimic': ['Normal', 'Status', 10, nan, nan],
#  'Screech': ['Normal', 'Status', 40, nan, 85.0],
#  'Double Team': ['Normal', 'Status', 15, nan, nan],
#  'Recover': ['Normal', 'Status', 10, nan, nan],
#  'Harden': ['Normal', 'Status', 30, nan, nan],
#  'Minimize': ['Normal', 'Status', 10, nan, nan],
#  'Smokescreen': ['Normal', 'Status', 20, nan, 100.0],
#  'Confuse Ray': ['Ghost', 'Status', 10, nan, 100.0],
#  'Withdraw': ['Water', 'Status', 40, nan, nan],
#  'Defense Curl': ['Normal', 'Status', 40, nan, nan],
#  'Barrier': ['Psychic', 'Status', 20, nan, nan],
#  'Light Screen': ['Psychic', 'Status', 30, nan, nan],
#  'Haze': ['Ice', 'Status', 30, nan, nan],
#  'Reflect': ['Psychic', 'Status', 20, nan, nan],
#  'Focus Energy': ['Normal', 'Status', 30, nan, nan],
#  'Bide': ['Normal', 'Physical', 10, nan, nan],
#  'Metronome': ['Normal', 'Status', 10, nan, nan],
#  'Mirror Move': ['Flying', 'Status', 20, nan, nan],
#  'Self-Destruct': ['Normal', 'Physical', 5, 200.0, 100.0],
#  'Egg Bomb': ['Normal', 'Physical', 10, 100.0, 75.0],
#  'Lick': ['Ghost', 'Physical', 30, 30.0, 100.0],
#  'Smog': ['Poison', 'Special', 20, 30.0, 70.0],
#  'Sludge': ['Poison', 'Special', 20, 65.0, 100.0],
#  'Bone Club': ['Ground', 'Physical', 20, 65.0, 85.0],
#  'Fire Blast': ['Fire', 'Special', 5, 110.0, 85.0],
#  'Waterfall': ['Water', 'Physical', 15, 80.0, 100.0],
#  'Clamp': ['Water', 'Physical', 15, 35.0, nan],
#  'Swift': ['Normal', 'Special', 20, 60.0, nan],
#  'Skull Bash': ['Normal', 'Physical', 10, 130.0, 100.0],
#  'Spike Cannon': ['Normal', 'Physical', 15, 20.0, 100.0],
#  'Constrict': ['Normal', 'Physical', 35, 10.0, 100.0],
#  'Amnesia': ['Psychic', 'Status', 20, nan, nan],
#  'Kinesis': ['Psychic', 'Status', 15, nan, 80.0],
#  'Soft-Boiled': ['Normal', 'Status', 10, nan, nan],
#  'High Jump Kick': ['Fighting', 'Physical', 10, 130.0, 90.0],
#  'Glare': ['Normal', 'Status', 30, nan, nan],
#  'Dream Eater': ['Psychic', 'Special', 15, 100.0, 100.0],
#  'Poison Gas': ['Poison', 'Status', 40, nan, nan],
#  'Barrage': ['Normal', 'Physical', 20, 15.0, 85.0],
#  'Leech Life': ['Bug', 'Physical', 10, 80.0, 100.0],
#  'Lovely Kiss': ['Normal', 'Status', 10, nan, 75.0],
#  'Sky Attack': ['Flying', 'Physical', 5, 140.0, 90.0],
#  'Transform': ['Normal', 'Status', 10, nan, nan],
#  'Bubble': ['Water', 'Special', 30, 40.0, 100.0],
#  'Dizzy Punch': ['Normal', 'Physical', 10, 70.0, 100.0],
#  'Spore': ['Grass', 'Status', 15, nan, 100.0],
#  'Flash': ['Normal', 'Status', 20, nan, nan],
#  'Psywave': ['Psychic', 'Special', 15, nan, nan],
#  'Splash': ['Normal', 'Status', 40, nan, nan],
#  'Acid Armor': ['Poison', 'Status', 20, nan, nan],
#  'Crabhammer': ['Water', 'Physical', 10, 100.0, nan],
#  'Explosion': ['Normal', 'Physical', 5, 250.0, 100.0],
#  'Fury Swipes': ['Normal', 'Physical', 15, 18.0, 80.0],
#  'Bonemerang': ['Ground', 'Physical', 10, 50.0, 90.0],
#  'Rest': ['Psychic', 'Status', 10, nan, nan],
#  'Rock Slide': ['Rock', 'Physical', 10, 75.0, 90.0],
#  'Hyper Fang': ['Normal', 'Physical', 15, 80.0, 90.0],
#  'Sharpen': ['Normal', 'Status', 30, nan, nan],
#  'Conversion': ['Normal', 'Status', 30, nan, nan],
#  'Tri Attack': ['Normal', 'Special', 10, 80.0, 100.0],
#  'Super Fang': ['Normal', 'Physical', 10, nan, 90.0],
#  'Slash': ['Normal', 'Physical', 20, 70.0, 100.0],
#  'Substitute': ['Normal', 'Status', 10, nan, nan],
#  'Struggle': ['Normal', 'Physical', 1, 50.0, nan],
#  'Sketch': ['Normal', 'Status', 1, nan, nan],
#  'Triple Kick': ['Fighting', 'Physical', 10, 10.0, 90.0],
#  'Thief': ['Dark', 'Physical', 25, 60.0, 100.0],
#  'Spider Web': ['Bug', 'Status', 10, nan, nan],
#  'Mind Reader': ['Normal', 'Status', 5, nan, nan],
#  'Nightmare': ['Ghost', 'Status', 15, nan, 100.0],
#  'Flame Wheel': ['Fire', 'Physical', 25, 60.0, 100.0],
#  'Snore': ['Normal', 'Special', 15, 50.0, 100.0],
#  'Curse': ['Ghost', 'Status', 10, nan, nan],
#  'Flail': ['Normal', 'Physical', 15, nan, 100.0],
#  'Conversion 2': ['Normal', 'Status', 30, nan, nan],
#  'Aeroblast': ['Flying', 'Special', 5, 100.0, 95.0],
#  'Cotton Spore': ['Grass', 'Status', 40, nan, nan],
#  'Reversal': ['Fighting', 'Physical', 15, nan, 100.0],
#  'Spite': ['Ghost', 'Status', 10, nan, 100.0],
#  'Powder Snow': ['Ice', 'Special', 25, 40.0, 100.0],
#  'Protect': ['Normal', 'Status', 10, nan, nan],
#  'Mach Punch': ['Fighting', 'Physical', 30, 40.0, 100.0],
#  'Scary Face': ['Normal', 'Status', 10, nan, nan],
#  'Feint Attack': ['Dark', 'Physical', 20, 60.0, nan],
#  'Sweet Kiss': ['Fairy', 'Status', 10, nan, 75.0],
#  'Belly Drum': ['Normal', 'Status', 10, nan, nan],
#  'Sludge Bomb': ['Poison', 'Special', 10, 90.0, 100.0],
#  'Mud-Slap': ['Ground', 'Special', 10, 20.0, 100.0],
#  'Octazooka': ['Water', 'Special', 10, 65.0, 85.0],
#  'Spikes': ['Ground', 'Status', 20, nan, nan],
#  'Zap Cannon': ['Electric', 'Special', 5, 120.0, 50.0],
#  'Foresight': ['Normal', 'Status', 40, nan, nan],
#  'Destiny Bond': ['Ghost', 'Status', 5, nan, nan],
#  'Perish Song': ['Normal', 'Status', 5, nan, nan],
#  'Icy Wind': ['Ice', 'Special', 15, 55.0, 95.0],
#  'Detect': ['Fighting', 'Status', 5, nan, nan],
#  'Bone Rush': ['Ground', 'Physical', 10, 25.0, nan],
#  'Lock-On': ['Normal', 'Status', 5, nan, nan],
#  'Outrage': ['Dragon', 'Physical', 10, 120.0, 100.0],
#  'Sandstorm': ['Rock', 'Status', 10, nan, nan],
#  'Giga Drain': ['Grass', 'Special', 10, 75.0, 100.0],
#  'Endure': ['Normal', 'Status', 10, nan, nan],
#  'Charm': ['Fairy', 'Status', 20, nan, 100.0],
#  'Rollout': ['Rock', 'Physical', 20, 30.0, 90.0],
#  'False Swipe': ['Normal', 'Physical', 40, 40.0, 100.0],
#  'Swagger': ['Normal', 'Status', 15, nan, nan],
#  'Milk Drink': ['Normal', 'Status', 10, nan, nan],
#  'Spark': ['Electric', 'Physical', 20, 65.0, 100.0],
#  'Fury Cutter': ['Bug', 'Physical', 20, 40.0, 95.0],
#  'Steel Wing': ['Steel', 'Physical', 25, 70.0, 90.0],
#  'Mean Look': ['Normal', 'Status', 5, nan, nan],
#  'Attract': ['Normal', 'Status', 15, nan, 100.0],
#  'Sleep Talk': ['Normal', 'Status', 10, nan, nan],
#  'Heal Bell': ['Normal', 'Status', 5, nan, nan],
#  'Return': ['Normal', 'Physical', 20, nan, 100.0],
#  'Present': ['Normal', 'Physical', 15, nan, 90.0],
#  'Frustration': ['Normal', 'Physical', 20, nan, 100.0],
#  'Safeguard': ['Normal', 'Status', 25, nan, nan],
#  'Pain Split': ['Normal', 'Status', 20, nan, nan],
#  'Sacred Fire': ['Fire', 'Physical', 5, 100.0, 95.0],
#  'Magnitude': ['Ground', 'Physical', 30, nan, 100.0],
#  'Dynamic Punch': ['Fighting', 'Physical', 5, 100.0, 50.0],
#  'Megahorn': ['Bug', 'Physical', 10, 120.0, 85.0],
#  'Dragon Breath': ['Dragon', 'Special', 20, 60.0, 100.0],
#  'Baton Pass': ['Normal', 'Status', 40, nan, nan],
#  'Encore': ['Normal', 'Status', 5, nan, 100.0],
#  'Pursuit': ['Dark', 'Physical', 20, 40.0, 100.0],
#  'Rapid Spin': ['Normal', 'Physical', 40, 20.0, 100.0],
#  'Sweet Scent': ['Normal', 'Status', 20, nan, 100.0],
#  'Iron Tail': ['Steel', 'Physical', 15, 100.0, 75.0],
#  'Metal Claw': ['Steel', 'Physical', 35, 50.0, 95.0],
#  'Vital Throw': ['Fighting', 'Physical', 10, 70.0, nan],
#  'Morning Sun': ['Normal', 'Status', 5, nan, nan],
#  'Synthesis': ['Grass', 'Status', 5, nan, nan],
#  'Moonlight': ['Fairy', 'Status', 5, nan, nan],
#  'Hidden Power': ['Normal', 'Special', 15, 60.0, 100.0],
#  'Cross Chop': ['Fighting', 'Physical', 5, 100.0, 80.0],
#  'Twister': ['Dragon', 'Special', 20, 40.0, 100.0],
#  'Rain Dance': ['Water', 'Status', 5, nan, nan],
#  'Sunny Day': ['Fire', 'Status', 5, nan, nan],
#  'Crunch': ['Dark', 'Physical', 15, 80.0, 100.0],
#  'Mirror Coat': ['Psychic', 'Special', 20, nan, 100.0],
#  'Psych Up': ['Normal', 'Status', 10, nan, nan],
#  'Extreme Speed': ['Normal', 'Physical', 5, 80.0, 100.0],
#  'Ancient Power': ['Rock', 'Special', 5, 60.0, 100.0],
#  'Shadow Ball': ['Ghost', 'Special', 15, 80.0, 100.0],
#  'Future Sight': ['Psychic', 'Special', 10, 120.0, nan],
#  'Rock Smash': ['Fighting', 'Physical', 15, 40.0, 100.0],
#  'Whirlpool': ['Water', 'Special', 15, 35.0, nan],
#  'Beat Up': ['Dark', 'Physical', 10, nan, 100.0],
#  'Fake Out': ['Normal', 'Physical', 10, 40.0, 100.0],
#  'Uproar': ['Normal', 'Special', 10, 90.0, 100.0],
#  'Stockpile': ['Normal', 'Status', 20, nan, nan],
#  'Spit Up': ['Normal', 'Special', 10, nan, 100.0],
#  'Swallow': ['Normal', 'Status', 10, nan, nan],
#  'Heat Wave': ['Fire', 'Special', 10, 95.0, 90.0],
#  'Hail': ['Ice', 'Status', 10, nan, nan],
#  'Torment': ['Dark', 'Status', 15, nan, 100.0],
#  'Flatter': ['Dark', 'Status', 15, nan, 100.0],
#  'Will-O-Wisp': ['Fire', 'Status', 15, nan, nan],
#  'Memento': ['Dark', 'Status', 10, nan, 100.0],
#  'Facade': ['Normal', 'Physical', 20, 70.0, 100.0],
#  'Focus Punch': ['Fighting', 'Physical', 20, 150.0, 100.0],
#  'Smelling Salts': ['Normal', 'Physical', 10, 70.0, 100.0],
#  'Follow Me': ['Normal', 'Status', 20, nan, nan],
#  'Nature Power': ['Normal', 'Status', 20, nan, nan],
#  'Charge': ['Electric', 'Status', 20, nan, nan],
#  'Taunt': ['Dark', 'Status', 20, nan, 100.0],
#  'Helping Hand': ['Normal', 'Status', 20, nan, nan],
#  'Trick': ['Psychic', 'Status', 10, nan, 100.0],
#  'Role Play': ['Psychic', 'Status', 10, nan, nan],
#  'Wish': ['Normal', 'Status', 10, nan, nan],
#  'Assist': ['Normal', 'Status', 20, nan, nan],
#  'Ingrain': ['Grass', 'Status', 20, nan, nan],
#  'Superpower': ['Fighting', 'Physical', 5, 120.0, 100.0],
#  'Magic Coat': ['Psychic', 'Status', 15, nan, nan],
#  'Recycle': ['Normal', 'Status', 10, nan, nan],
#  'Revenge': ['Fighting', 'Physical', 10, 60.0, 100.0],
#  'Brick Break': ['Fighting', 'Physical', 15, 75.0, 100.0],
#  'Yawn': ['Normal', 'Status', 10, nan, nan],
#  'Knock Off': ['Dark', 'Physical', 20, 65.0, 100.0],
#  'Endeavor': ['Normal', 'Physical', 5, nan, 100.0],
#  'Eruption': ['Fire', 'Special', 5, 150.0, 100.0],
#  'Skill Swap': ['Psychic', 'Status', 10, nan, nan],
#  'Imprison': ['Psychic', 'Status', 10, nan, nan],
#  'Refresh': ['Normal', 'Status', 20, nan, nan],
#  'Grudge': ['Ghost', 'Status', 5, nan, nan],
#  'Snatch': ['Dark', 'Status', 10, nan, nan],
#  'Secret Power': ['Normal', 'Physical', 20, 70.0, 100.0],
#  'Dive': ['Water', 'Physical', 10, 80.0, 100.0],
#  'Arm Thrust': ['Fighting', 'Physical', 20, 15.0, 100.0],
#  'Camouflage': ['Normal', 'Status', 20, nan, nan],
#  'Tail Glow': ['Bug', 'Status', 20, nan, nan],
#  'Luster Purge': ['Psychic', 'Special', 5, 70.0, 100.0],
#  'Mist Ball': ['Psychic', 'Special', 5, 70.0, 100.0],
#  'Feather Dance': ['Flying', 'Status', 15, nan, 100.0],
#  'Teeter Dance': ['Normal', 'Status', 20, nan, 100.0],
#  'Blaze Kick': ['Fire', 'Physical', 10, 85.0, 90.0],
#  'Mud Sport': ['Ground', 'Status', 15, nan, nan],
#  'Ice Ball': ['Ice', 'Physical', 20, 30.0, 90.0],
#  'Needle Arm': ['Grass', 'Physical', 15, 60.0, 100.0],
#  'Slack Off': ['Normal', 'Status', 10, nan, nan],
#  'Hyper Voice': ['Normal', 'Special', 10, 90.0, 100.0],
#  'Poison Fang': ['Poison', 'Physical', 15, 50.0, 100.0],
#  'Crush Claw': ['Normal', 'Physical', 10, 75.0, 95.0],
#  'Blast Burn': ['Fire', 'Special', 5, 150.0, 90.0],
#  'Hydro Cannon': ['Water', 'Special', 5, 150.0, 90.0],
#  'Meteor Mash': ['Steel', 'Physical', 10, 90.0, nan],
#  'Astonish': ['Ghost', 'Physical', 15, 30.0, 100.0],
#  'Weather Ball': ['Normal', 'Special', 10, 50.0, 100.0],
#  'Aromatherapy': ['Grass', 'Status', 5, nan, nan],
#  'Fake Tears': ['Dark', 'Status', 20, nan, 100.0],
#  'Air Cutter': ['Flying', 'Special', 25, 60.0, 95.0],
#  'Overheat': ['Fire', 'Special', 5, 130.0, 90.0],
#  'Odor Sleuth': ['Normal', 'Status', 40, nan, nan],
#  'Rock Tomb': ['Rock', 'Physical', 15, 60.0, nan],
#  'Silver Wind': ['Bug', 'Special', 5, 60.0, 100.0],
#  'Metal Sound': ['Steel', 'Status', 40, nan, 85.0],
#  'Grass Whistle': ['Grass', 'Status', 15, nan, 55.0],
#  'Tickle': ['Normal', 'Status', 20, nan, 100.0],
#  'Cosmic Power': ['Psychic', 'Status', 20, nan, nan],
#  'Water Spout': ['Water', 'Special', 5, 150.0, 100.0],
#  'Signal Beam': ['Bug', 'Special', 15, 75.0, 100.0],
#  'Shadow Punch': ['Ghost', 'Physical', 20, 60.0, nan],
#  'Extrasensory': ['Psychic', 'Special', 20, 80.0, 100.0],
#  'Sky Uppercut': ['Fighting', 'Physical', 15, 85.0, 90.0],
#  'Sand Tomb': ['Ground', 'Physical', 15, 35.0, nan],
#  'Sheer Cold': ['Ice', 'Special', 5, nan, nan],
#  'Muddy Water': ['Water', 'Special', 10, 90.0, 85.0],
#  'Bullet Seed': ['Grass', 'Physical', 30, 25.0, 100.0],
#  'Aerial Ace': ['Flying', 'Physical', 20, 60.0, nan],
#  'Icicle Spear': ['Ice', 'Physical', 30, 25.0, 100.0],
#  'Iron Defense': ['Steel', 'Status', 15, nan, nan],
#  'Block': ['Normal', 'Status', 5, nan, nan],
#  'Howl': ['Normal', 'Status', 40, nan, nan],
#  'Dragon Claw': ['Dragon', 'Physical', 15, 80.0, 100.0],
#  'Frenzy Plant': ['Grass', 'Special', 5, 150.0, 90.0],
#  'Bulk Up': ['Fighting', 'Status', 20, nan, nan],
#  'Bounce': ['Flying', 'Physical', 5, 85.0, 85.0],
#  'Mud Shot': ['Ground', 'Special', 15, 55.0, 95.0],
#  'Poison Tail': ['Poison', 'Physical', 25, 50.0, 100.0],
#  'Covet': ['Normal', 'Physical', 25, 60.0, 100.0],
#  'Volt Tackle': ['Electric', 'Physical', 15, 120.0, 100.0],
#  'Magical Leaf': ['Grass', 'Special', 20, 60.0, nan],
#  'Water Sport': ['Water', 'Status', 15, nan, nan],
#  'Calm Mind': ['Psychic', 'Status', 20, nan, nan],
#  'Leaf Blade': ['Grass', 'Physical', 15, 90.0, 100.0],
#  'Dragon Dance': ['Dragon', 'Status', 20, nan, nan],
#  'Rock Blast': ['Rock', 'Physical', 10, 25.0, nan],
#  'Shock Wave': ['Electric', 'Special', 20, 60.0, nan],
#  'Water Pulse': ['Water', 'Special', 20, 60.0, 100.0],
#  'Doom Desire': ['Steel', 'Special', 5, 140.0, nan],
#  'Psycho Boost': ['Psychic', 'Special', 5, 140.0, 90.0],
#  'Roost': ['Flying', 'Status', 10, nan, nan],
#  'Gravity': ['Psychic', 'Status', 5, nan, nan],
#  'Miracle Eye': ['Psychic', 'Status', 40, nan, nan],
#  'Wake-Up Slap': ['Fighting', 'Physical', 10, 70.0, 100.0],
#  'Hammer Arm': ['Fighting', 'Physical', 10, 100.0, 90.0],
#  'Gyro Ball': ['Steel', 'Physical', 5, nan, 100.0],
#  'Healing Wish': ['Psychic', 'Status', 10, nan, nan],
#  'Brine': ['Water', 'Special', 10, 65.0, 100.0],
#  'Natural Gift': ['Normal', 'Physical', 15, nan, 100.0],
#  'Feint': ['Normal', 'Physical', 10, 30.0, 100.0],
#  'Pluck': ['Flying', 'Physical', 20, 60.0, 100.0],
#  'Tailwind': ['Flying', 'Status', 15, nan, nan],
#  'Acupressure': ['Normal', 'Status', 30, nan, nan],
#  'Metal Burst': ['Steel', 'Physical', 10, nan, 100.0],
#  'U-turn': ['Bug', 'Physical', 20, 70.0, 100.0],
#  'Close Combat': ['Fighting', 'Physical', 5, 120.0, 100.0],
#  'Payback': ['Dark', 'Physical', 10, 50.0, 100.0],
#  'Assurance': ['Dark', 'Physical', 10, 60.0, 100.0],
#  'Embargo': ['Dark', 'Status', 15, nan, 100.0],
#  'Fling': ['Dark', 'Physical', 10, nan, 100.0],
#  'Psycho Shift': ['Psychic', 'Status', 10, nan, nan],
#  'Trump Card': ['Normal', 'Special', 5, nan, nan],
#  'Heal Block': ['Psychic', 'Status', 15, nan, 100.0],
#  'Wring Out': ['Normal', 'Special', 5, nan, 100.0],
#  'Power Trick': ['Psychic', 'Status', 10, nan, nan],
#  'Gastro Acid': ['Poison', 'Status', 10, nan, 100.0],
#  'Lucky Chant': ['Normal', 'Status', 30, nan, nan],
#  'Me First': ['Normal', 'Status', 20, nan, nan],
#  'Copycat': ['Normal', 'Status', 20, nan, nan],
#  'Power Swap': ['Psychic', 'Status', 10, nan, nan],
#  'Guard Swap': ['Psychic', 'Status', 10, nan, nan],
#  'Punishment': ['Dark', 'Physical', 5, nan, 100.0],
#  'Last Resort': ['Normal', 'Physical', 5, 140.0, 100.0],
#  'Worry Seed': ['Grass', 'Status', 10, nan, 100.0],
#  'Sucker Punch': ['Dark', 'Physical', 5, 70.0, 100.0],
#  'Toxic Spikes': ['Poison', 'Status', 20, nan, nan],
#  'Heart Swap': ['Psychic', 'Status', 10, nan, nan],
#  'Aqua Ring': ['Water', 'Status', 20, nan, nan],
#  'Magnet Rise': ['Electric', 'Status', 10, nan, nan],
#  'Flare Blitz': ['Fire', 'Physical', 15, 120.0, 100.0],
#  'Force Palm': ['Fighting', 'Physical', 10, 60.0, 100.0],
#  'Aura Sphere': ['Fighting', 'Special', 20, 80.0, nan],
#  'Rock Polish': ['Rock', 'Status', 20, nan, nan],
#  'Poison Jab': ['Poison', 'Physical', 20, 80.0, 100.0],
#  'Dark Pulse': ['Dark', 'Special', 15, 80.0, 100.0],
#  'Night Slash': ['Dark', 'Physical', 15, 70.0, 100.0],
#  'Aqua Tail': ['Water', 'Physical', 10, 90.0, 90.0],
#  'Seed Bomb': ['Grass', 'Physical', 15, 80.0, 100.0],
#  'Air Slash': ['Flying', 'Special', 15, 75.0, 95.0],
#  'X-Scissor': ['Bug', 'Physical', 15, 80.0, 100.0],
#  'Bug Buzz': ['Bug', 'Special', 10, 90.0, 100.0],
#  'Dragon Pulse': ['Dragon', 'Special', 10, 85.0, 100.0],
#  'Dragon Rush': ['Dragon', 'Physical', 10, 100.0, 75.0],
#  'Power Gem': ['Rock', 'Special', 20, 80.0, 100.0],
#  'Drain Punch': ['Fighting', 'Physical', 10, 75.0, 100.0],
#  'Vacuum Wave': ['Fighting', 'Special', 30, 40.0, 100.0],
#  'Focus Blast': ['Fighting', 'Special', 5, 120.0, 70.0],
#  'Energy Ball': ['Grass', 'Special', 10, 90.0, 100.0],
#  'Brave Bird': ['Flying', 'Physical', 15, 120.0, 100.0],
#  'Earth Power': ['Ground', 'Special', 10, 90.0, 100.0],
#  'Switcheroo': ['Dark', 'Status', 10, nan, 100.0],
#  'Giga Impact': ['Normal', 'Physical', 5, 150.0, 90.0],
#  'Nasty Plot': ['Dark', 'Status', 20, nan, nan],
#  'Bullet Punch': ['Steel', 'Physical', 30, 40.0, 100.0],
#  'Avalanche': ['Ice', 'Physical', 10, 60.0, 100.0],
#  'Ice Shard': ['Ice', 'Physical', 30, 40.0, 100.0],
#  'Shadow Claw': ['Ghost', 'Physical', 15, 70.0, 100.0],
#  'Thunder Fang': ['Electric', 'Physical', 15, 65.0, 95.0],
#  'Ice Fang': ['Ice', 'Physical', 15, 65.0, 95.0],
#  'Fire Fang': ['Fire', 'Physical', 15, 65.0, 95.0],
#  'Shadow Sneak': ['Ghost', 'Physical', 30, 40.0, 100.0],
#  'Mud Bomb': ['Ground', 'Special', 10, 65.0, 85.0],
#  'Psycho Cut': ['Psychic', 'Physical', 20, 70.0, 100.0],
#  'Zen Headbutt': ['Psychic', 'Physical', 15, 80.0, 90.0],
#  'Mirror Shot': ['Steel', 'Special', 10, 65.0, 85.0],
#  'Flash Cannon': ['Steel', 'Special', 10, 80.0, 100.0],
#  'Rock Climb': ['Normal', 'Physical', 20, 90.0, 85.0],
#  'Defog': ['Flying', 'Status', 15, nan, nan],
#  'Trick Room': ['Psychic', 'Status', 5, nan, nan],
#  'Draco Meteor': ['Dragon', 'Special', 5, 130.0, 90.0],
#  'Discharge': ['Electric', 'Special', 15, 80.0, 100.0],
#  'Lava Plume': ['Fire', 'Special', 15, 80.0, 100.0],
#  'Leaf Storm': ['Grass', 'Special', 5, 130.0, 90.0],
#  'Power Whip': ['Grass', 'Physical', 10, 120.0, 85.0],
#  'Rock Wrecker': ['Rock', 'Physical', 5, 150.0, 90.0],
#  'Cross Poison': ['Poison', 'Physical', 20, 70.0, 100.0],
#  'Gunk Shot': ['Poison', 'Physical', 5, 120.0, nan],
#  'Iron Head': ['Steel', 'Physical', 15, 80.0, 100.0],
#  'Magnet Bomb': ['Steel', 'Physical', 20, 60.0, nan],
#  'Stone Edge': ['Rock', 'Physical', 5, 100.0, 80.0],
#  'Captivate': ['Normal', 'Status', 20, nan, 100.0],
#  'Stealth Rock': ['Rock', 'Status', 20, nan, nan],
#  'Grass Knot': ['Grass', 'Special', 20, nan, 100.0],
#  'Chatter': ['Flying', 'Special', 20, 65.0, 100.0],
#  'Judgment': ['Normal', 'Special', 10, 100.0, 100.0],
#  'Bug Bite': ['Bug', 'Physical', 20, 60.0, 100.0],
#  'Charge Beam': ['Electric', 'Special', 10, 50.0, 90.0],
#  'Wood Hammer': ['Grass', 'Physical', 15, 120.0, 100.0],
#  'Aqua Jet': ['Water', 'Physical', 20, 40.0, 100.0],
#  'Attack Order': ['Bug', 'Physical', 15, 90.0, 100.0],
#  'Defend Order': ['Bug', 'Status', 10, nan, nan],
#  'Heal Order': ['Bug', 'Status', 10, nan, nan],
#  'Head Smash': ['Rock', 'Physical', 5, 150.0, 80.0],
#  'Double Hit': ['Normal', 'Physical', 10, 35.0, 90.0],
#  'Roar of Time': ['Dragon', 'Special', 5, 150.0, 90.0],
#  'Spacial Rend': ['Dragon', 'Special', 5, 100.0, 95.0],
#  'Lunar Dance': ['Psychic', 'Status', 10, nan, nan],
#  'Crush Grip': ['Normal', 'Physical', 5, nan, 100.0],
#  'Magma Storm': ['Fire', 'Special', 5, 100.0, nan],
#  'Dark Void': ['Dark', 'Status', 10, nan, nan],
#  'Seed Flare': ['Grass', 'Special', 5, 120.0, 85.0],
#  'Ominous Wind': ['Ghost', 'Special', 5, 60.0, 100.0],
#  'Shadow Force': ['Ghost', 'Physical', 5, 120.0, 100.0],
#  'Hone Claws': ['Dark', 'Status', 15, nan, nan],
#  'Wide Guard': ['Rock', 'Status', 10, nan, nan],
#  'Guard Split': ['Psychic', 'Status', 10, nan, nan],
#  'Power Split': ['Psychic', 'Status', 10, nan, nan],
#  'Wonder Room': ['Psychic', 'Status', 10, nan, nan],
#  'Psyshock': ['Psychic', 'Special', 10, 80.0, 100.0],
#  'Venoshock': ['Poison', 'Special', 10, 65.0, 100.0],
#  'Autotomize': ['Steel', 'Status', 15, nan, nan],
#  'Rage Powder': ['Bug', 'Status', 20, nan, nan],
#  'Telekinesis': ['Psychic', 'Status', 15, nan, nan],
#  'Magic Room': ['Psychic', 'Status', 10, nan, nan],
#  'Smack Down': ['Rock', 'Physical', 15, 50.0, 100.0],
#  'Storm Throw': ['Fighting', 'Physical', 10, 60.0, 100.0],
#  'Flame Burst': ['Fire', 'Special', 15, 70.0, 100.0],
#  'Sludge Wave': ['Poison', 'Special', 10, 95.0, 100.0],
#  'Quiver Dance': ['Bug', 'Status', 20, nan, nan],
#  'Heavy Slam': ['Steel', 'Physical', 10, nan, 100.0],
#  'Synchronoise': ['Psychic', 'Special', 10, 120.0, 100.0],
#  'Electro Ball': ['Electric', 'Special', 10, nan, 100.0],
#  'Soak': ['Water', 'Status', 20, nan, 100.0],
#  'Flame Charge': ['Fire', 'Physical', 20, 50.0, 100.0],
#  'Coil': ['Poison', 'Status', 20, nan, nan],
#  'Low Sweep': ['Fighting', 'Physical', 20, 65.0, 100.0],
#  'Acid Spray': ['Poison', 'Special', 20, 40.0, 100.0],
#  'Foul Play': ['Dark', 'Physical', 15, 95.0, 100.0],
#  'Simple Beam': ['Normal', 'Status', 15, nan, 100.0],
#  'Entrainment': ['Normal', 'Status', 15, nan, 100.0],
#  'After You': ['Normal', 'Status', 15, nan, nan],
#  'Round': ['Normal', 'Special', 15, 60.0, 100.0],
#  'Echoed Voice': ['Normal', 'Special', 15, 40.0, 100.0],
#  'Chip Away': ['Normal', 'Physical', 20, 70.0, 100.0],
#  'Clear Smog': ['Poison', 'Special', 15, 50.0, nan],
#  'Stored Power': ['Psychic', 'Special', 10, 20.0, 100.0],
#  'Quick Guard': ['Fighting', 'Status', 15, nan, nan],
#  'Ally Switch': ['Psychic', 'Status', 15, nan, nan],
#  'Scald': ['Water', 'Special', 15, 80.0, 100.0],
#  'Shell Smash': ['Normal', 'Status', 15, nan, nan],
#  'Heal Pulse': ['Psychic', 'Status', 10, nan, nan],
#  'Hex': ['Ghost', 'Special', 10, 65.0, 100.0],
#  'Sky Drop': ['Flying', 'Physical', 10, 60.0, 100.0],
#  'Shift Gear': ['Steel', 'Status', 10, nan, nan],
#  'Circle Throw': ['Fighting', 'Physical', 10, 60.0, 90.0],
#  'Incinerate': ['Fire', 'Special', 15, 60.0, 100.0],
#  'Quash': ['Dark', 'Status', 15, nan, 100.0],
#  'Acrobatics': ['Flying', 'Physical', 15, 55.0, 100.0],
#  'Reflect Type': ['Normal', 'Status', 15, nan, nan],
#  'Retaliate': ['Normal', 'Physical', 5, 70.0, 100.0],
#  'Final Gambit': ['Fighting', 'Special', 5, nan, 100.0],
#  'Bestow': ['Normal', 'Status', 15, nan, nan],
#  'Inferno': ['Fire', 'Special', 5, 100.0, 50.0],
#  'Water Pledge': ['Water', 'Special', 10, 80.0, 100.0],
#  'Fire Pledge': ['Fire', 'Special', 10, 80.0, 100.0],
#  'Grass Pledge': ['Grass', 'Special', 10, 80.0, 100.0],
#  'Volt Switch': ['Electric', 'Special', 20, 70.0, 100.0],
#  'Struggle Bug': ['Bug', 'Special', 20, 50.0, 100.0],
#  'Bulldoze': ['Ground', 'Physical', 20, 60.0, 100.0],
#  'Frost Breath': ['Ice', 'Special', 10, 60.0, 90.0],
#  'Dragon Tail': ['Dragon', 'Physical', 10, 60.0, 90.0],
#  'Work Up': ['Normal', 'Status', 30, nan, nan],
#  'Electroweb': ['Electric', 'Special', 15, 55.0, 95.0],
#  'Wild Charge': ['Electric', 'Physical', 15, 90.0, 100.0],
#  'Drill Run': ['Ground', 'Physical', 10, 80.0, 95.0],
#  'Dual Chop': ['Dragon', 'Physical', 15, 40.0, 90.0],
#  'Heart Stamp': ['Psychic', 'Physical', 25, 60.0, 100.0],
#  'Horn Leech': ['Grass', 'Physical', 10, 75.0, 100.0],
#  'Sacred Sword': ['Fighting', 'Physical', 15, 90.0, 100.0],
#  'Razor Shell': ['Water', 'Physical', 10, 75.0, 95.0],
#  'Heat Crash': ['Fire', 'Physical', 10, nan, 100.0],
#  'Leaf Tornado': ['Grass', 'Special', 10, 65.0, 90.0],
#  'Steamroller': ['Bug', 'Physical', 20, 65.0, 100.0],
#  'Cotton Guard': ['Grass', 'Status', 10, nan, nan],
#  'Night Daze': ['Dark', 'Special', 10, 85.0, 95.0],
#  'Psystrike': ['Psychic', 'Special', 10, 100.0, 100.0],
#  'Tail Slap': ['Normal', 'Physical', 10, 25.0, 85.0],
#  'Hurricane': ['Flying', 'Special', 10, 110.0, 70.0],
#  'Head Charge': ['Normal', 'Physical', 15, 120.0, 100.0],
#  'Gear Grind': ['Steel', 'Physical', 15, 50.0, 85.0],
#  'Searing Shot': ['Fire', 'Special', 5, 100.0, 100.0],
#  'Techno Blast': ['Normal', 'Special', 5, 120.0, 100.0],
#  'Relic Song': ['Normal', 'Special', 10, 75.0, 100.0],
#  'Secret Sword': ['Fighting', 'Special', 10, 85.0, 100.0],
#  'Glaciate': ['Ice', 'Special', 10, 65.0, 95.0],
#  'Bolt Strike': ['Electric', 'Physical', 5, 130.0, 85.0],
#  'Blue Flare': ['Fire', 'Special', 5, 130.0, 85.0],
#  'Fiery Dance': ['Fire', 'Special', 10, 80.0, 100.0],
#  'Freeze Shock': ['Ice', 'Physical', 5, 140.0, 90.0],
#  'Ice Burn': ['Ice', 'Special', 5, 140.0, 90.0],
#  'Snarl': ['Dark', 'Special', 15, 55.0, 95.0],
#  'Icicle Crash': ['Ice', 'Physical', 10, 85.0, 90.0],
#  'V-create': ['Fire', 'Physical', 5, 180.0, 95.0],
#  'Fusion Flare': ['Fire', 'Special', 5, 100.0, 100.0],
#  'Fusion Bolt': ['Electric', 'Physical', 5, 100.0, 100.0],
#  'Flying Press': ['Fighting', 'Physical', 10, 100.0, 95.0],
#  'Mat Block': ['Fighting', 'Status', 10, nan, nan],
#  'Belch': ['Poison', 'Special', 10, 120.0, 90.0],
#  'Rototiller': ['Ground', 'Status', 10, nan, nan],
#  'Sticky Web': ['Bug', 'Status', 20, nan, nan],
#  'Fell Stinger': ['Bug', 'Physical', 25, 50.0, 100.0],
#  'Phantom Force': ['Ghost', 'Physical', 10, 90.0, 100.0],
#  'Trick-or-Treat': ['Ghost', 'Status', 20, nan, 100.0],
#  'Noble Roar': ['Normal', 'Status', 30, nan, 100.0],
#  'Ion Deluge': ['Electric', 'Status', 25, nan, nan],
#  'Parabolic Charge': ['Electric', 'Special', 20, 65.0, 100.0],
#  "Forest's Curse": ['Grass', 'Status', 20, nan, 100.0],
#  'Petal Blizzard': ['Grass', 'Physical', 15, 90.0, 100.0],
#  'Freeze-Dry': ['Ice', 'Special', 20, 70.0, 100.0],
#  'Disarming Voice': ['Fairy', 'Special', 15, 40.0, nan],
#  'Parting Shot': ['Dark', 'Status', 20, nan, 100.0],
#  'Topsy-Turvy': ['Dark', 'Status', 20, nan, nan],
#  'Draining Kiss': ['Fairy', 'Special', 10, 50.0, 100.0],
#  'Crafty Shield': ['Fairy', 'Status', 10, nan, nan],
#  'Flower Shield': ['Fairy', 'Status', 10, nan, nan],
#  'Grassy Terrain': ['Grass', 'Status', 10, nan, nan],
#  'Misty Terrain': ['Fairy', 'Status', 10, nan, nan],
#  'Electrify': ['Electric', 'Status', 20, nan, nan],
#  'Play Rough': ['Fairy', 'Physical', 10, 90.0, 90.0],
#  'Fairy Wind': ['Fairy', 'Special', 30, 40.0, 100.0],
#  'Moonblast': ['Fairy', 'Special', 15, 95.0, 100.0],
#  'Boomburst': ['Normal', 'Special', 10, 140.0, 100.0],
#  'Fairy Lock': ['Fairy', 'Status', 10, nan, nan],
#  "King's Shield": ['Steel', 'Status', 10, nan, nan],
#  'Play Nice': ['Normal', 'Status', 20, nan, nan],
#  'Confide': ['Normal', 'Status', 20, nan, nan],
#  'Diamond Storm': ['Rock', 'Physical', 5, 100.0, 95.0],
#  'Steam Eruption': ['Water', 'Special', 5, 110.0, 95.0],
#  'Hyperspace Hole': ['Psychic', 'Special', 5, 80.0, nan],
#  'Water Shuriken': ['Water', 'Special', 20, 15.0, 100.0],
#  'Mystical Fire': ['Fire', 'Special', 10, 75.0, 100.0],
#  'Spiky Shield': ['Grass', 'Status', 10, nan, nan],
#  'Aromatic Mist': ['Fairy', 'Status', 20, nan, nan],
#  'Eerie Impulse': ['Electric', 'Status', 15, nan, 100.0],
#  'Venom Drench': ['Poison', 'Status', 20, nan, 100.0],
#  'Powder': ['Bug', 'Status', 20, nan, 100.0],
#  'Geomancy': ['Fairy', 'Status', 10, nan, nan],
#  'Magnetic Flux': ['Electric', 'Status', 20, nan, nan],
#  'Happy Hour': ['Normal', 'Status', 30, nan, nan],
#  'Electric Terrain': ['Electric', 'Status', 10, nan, nan],
#  'Dazzling Gleam': ['Fairy', 'Special', 10, 80.0, 100.0],
#  'Celebrate': ['Normal', 'Status', 40, nan, nan],
#  'Hold Hands': ['Normal', 'Status', 40, nan, nan],
#  'Baby-Doll Eyes': ['Fairy', 'Status', 30, nan, 100.0],
#  'Nuzzle': ['Electric', 'Physical', 20, 20.0, 100.0],
#  'Hold Back': ['Normal', 'Physical', 40, 40.0, 100.0],
#  'Infestation': ['Bug', 'Special', 20, 20.0, 100.0],
#  'Power-Up Punch': ['Fighting', 'Physical', 20, 40.0, 100.0],
#  'Oblivion Wing': ['Flying', 'Special', 10, 80.0, 100.0],
#  'Thousand Arrows': ['Ground', 'Physical', 10, 90.0, 100.0],
#  'Thousand Waves': ['Ground', 'Physical', 10, 90.0, 100.0],
#  "Land's Wrath": ['Ground', 'Physical', 10, 90.0, 100.0],
#  'Light of Ruin': ['Fairy', 'Special', 5, 140.0, 90.0],
#  'Origin Pulse': ['Water', 'Special', 10, 110.0, 85.0],
#  'Precipice Blades': ['Ground', 'Physical', 10, 120.0, 85.0],
#  'Dragon Ascent': ['Flying', 'Physical', 5, 120.0, 100.0],
#  'Hyperspace Fury': ['Dark', 'Physical', 5, 100.0, nan],
#  'Breakneck Blitz': ['Normal', 'Special', 1, nan, nan],
#  'All-Out Pummeling': ['Fighting', 'Special', 1, nan, nan],
#  'Supersonic Skystrike': ['Flying', 'Special', 1, nan, nan],
#  'Acid Downpour': ['Poison', 'Special', 1, nan, nan],
#  'Tectonic Rage': ['Ground', 'Special', 1, nan, nan],
#  'Continental Crush': ['Rock', 'Special', 1, nan, nan],
#  'Savage Spin-Out': ['Bug', 'Special', 1, nan, nan],
#  'Never-Ending Nightmare': ['Ghost', 'Special', 1, nan, nan],
#  'Corkscrew Crash': ['Steel', 'Special', 1, nan, nan],
#  'Inferno Overdrive': ['Fire', 'Special', 1, nan, nan],
#  'Hydro Vortex': ['Water', 'Special', 1, nan, nan],
#  'Bloom Doom': ['Grass', 'Special', 1, nan, nan],
#  'Gigavolt Havoc': ['Electric', 'Special', 1, nan, nan],
#  'Shattered Psyche': ['Psychic', 'Special', 1, nan, nan],
#  'Subzero Slammer': ['Ice', 'Special', 1, nan, nan],
#  'Devastating Drake': ['Dragon', 'Special', 1, nan, nan],
#  'Black Hole Eclipse': ['Dark', 'Special', 1, nan, nan],
#  'Twinkle Tackle': ['Fairy', 'Special', 1, nan, nan],
#  'Catastropika': ['Electric', 'Physical', 1, 210.0, nan],
#  'Shore Up': ['Ground', 'Status', 10, nan, nan],
#  'First Impression': ['Bug', 'Physical', 10, 90.0, 100.0],
#  'Baneful Bunker': ['Poison', 'Status', 10, nan, nan],
#  'Spirit Shackle': ['Ghost', 'Physical', 10, 80.0, 100.0],
#  'Darkest Lariat': ['Dark', 'Physical', 10, 85.0, 100.0],
#  'Sparkling Aria': ['Water', 'Special', 10, 90.0, 100.0],
#  'Ice Hammer': ['Ice', 'Physical', 10, 100.0, 90.0],
#  'Floral Healing': ['Fairy', 'Status', 10, nan, nan],
#  'High Horsepower': ['Ground', 'Physical', 10, 95.0, 95.0],
#  'Strength Sap': ['Grass', 'Status', 10, nan, 100.0],
#  'Solar Blade': ['Grass', 'Physical', 10, 125.0, 100.0],
#  'Leafage': ['Grass', 'Physical', 40, 40.0, 100.0],
#  'Spotlight': ['Normal', 'Status', 15, nan, nan],
#  'Toxic Thread': ['Poison', 'Status', 20, nan, 100.0],
#  'Laser Focus': ['Normal', 'Status', 30, nan, nan],
#  'Gear Up': ['Steel', 'Status', 20, nan, nan],
#  'Throat Chop': ['Dark', 'Physical', 15, 80.0, 100.0],
#  'Pollen Puff': ['Bug', 'Special', 15, 90.0, 100.0],
#  'Anchor Shot': ['Steel', 'Physical', 20, 80.0, 100.0],
#  'Psychic Terrain': ['Psychic', 'Status', 10, nan, nan],
#  'Lunge': ['Bug', 'Physical', 15, 80.0, 100.0],
#  'Fire Lash': ['Fire', 'Physical', 15, 80.0, 100.0],
#  'Power Trip': ['Dark', 'Physical', 10, 20.0, 100.0],
#  'Burn Up': ['Fire', 'Special', 5, 130.0, 100.0],
#  'Speed Swap': ['Psychic', 'Status', 10, nan, nan],
#  'Smart Strike': ['Steel', 'Physical', 10, 70.0, nan],
#  'Purify': ['Poison', 'Status', 20, nan, nan],
#  'Revelation Dance': ['Normal', 'Special', 15, 90.0, 100.0],
#  'Core Enforcer': ['Dragon', 'Special', 10, 100.0, 100.0],
#  'Trop Kick': ['Grass', 'Physical', 15, 70.0, 100.0],
#  'Instruct': ['Psychic', 'Status', 15, nan, nan],
#  'Beak Blast': ['Flying', 'Physical', 15, 100.0, 100.0],
#  'Clanging Scales': ['Dragon', 'Special', 5, 110.0, 100.0],
#  'Dragon Hammer': ['Dragon', 'Physical', 15, 90.0, 100.0],
#  'Brutal Swing': ['Dark', 'Physical', 20, 60.0, 100.0],
#  'Aurora Veil': ['Ice', 'Status', 20, nan, nan],
#  'Sinister Arrow Raid': ['Ghost', 'Physical', 1, 180.0, nan],
#  'Malicious Moonsault': ['Dark', 'Physical', 1, 180.0, nan],
#  'Oceanic Operetta': ['Water', 'Special', 1, 195.0, nan],
#  'Guardian of Alola': ['Fairy', 'Special', 1, nan, nan],
#  'Soul-Stealing 7-Star Strike': ['Ghost', 'Physical', 1, 195.0, nan],
#  'Stoked Sparksurfer': ['Electric', 'Special', 1, 175.0, nan],
#  'Pulverizing Pancake': ['Normal', 'Physical', 1, 210.0, nan],
#  'Extreme Evoboost': ['Normal', 'Status', 1, nan, nan],
#  'Genesis Supernova': ['Psychic', 'Special', 1, 185.0, nan],
#  'Shell Trap': ['Fire', 'Special', 5, 150.0, 100.0],
#  'Fleur Cannon': ['Fairy', 'Special', 5, 130.0, 90.0],
#  'Psychic Fangs': ['Psychic', 'Physical', 10, 85.0, 100.0],
#  'Stomping Tantrum': ['Ground', 'Physical', 10, 75.0, 100.0],
#  'Shadow Bone': ['Ghost', 'Physical', 10, 85.0, 100.0],
#  'Accelerock': ['Rock', 'Physical', 20, 40.0, 100.0],
#  'Liquidation': ['Water', 'Physical', 10, 85.0, 100.0],
#  'Prismatic Laser': ['Psychic', 'Special', 10, 160.0, 100.0],
#  'Spectral Thief': ['Ghost', 'Physical', 10, 90.0, 100.0],
#  'Sunsteel Strike': ['Steel', 'Physical', 5, 100.0, 100.0],
#  'Moongeist Beam': ['Ghost', 'Special', 5, 100.0, 100.0],
#  'Tearful Look': ['Normal', 'Status', 20, nan, nan],
#  'Zing Zap': ['Electric', 'Physical', 10, 80.0, 100.0],
#  "Nature's Madness": ['Fairy', 'Special', 10, nan, 90.0],
#  'Multi-Attack': ['Normal', 'Physical', 10, 90.0, 100.0],
#  '10,000,000 Volt Thunderbolt': ['Electric', 'Special', 1, 195.0, nan],
#  'Mind Blown': ['Fire', 'Special', 5, 150.0, 100.0],
#  'Plasma Fists': ['Electric', 'Physical', 15, 100.0, 100.0],
#  'Photon Geyser': ['Psychic', 'Special', 5, 100.0, 100.0],
#  'Light That Burns the Sky': ['Psychic', 'Special', 1, 200.0, nan],
#  'Searing Sunraze Smash': ['Steel', 'Special', 1, 200.0, nan],
#  'Menacing Moonraze Maelstrom': ['Ghost', 'Special', 1, 200.0, nan],
#  "Let's Snuggle Forever": ['Fairy', 'Physical', 1, 190.0, nan],
#  'Splintered Stormshards': ['Rock', 'Physical', 1, 190.0, nan],
#  'Clangorous Soulblaze': ['Dragon', 'Special', 1, 185.0, nan]}

# %%
## convert from data frame to dict of pokemon name-->[type, category, pp, power, accuracy]
pokeDict = pokemon.to_dict()
pokeNameDict = {}
for key in pokeDict['Name']:
    pokeNameDict[pokeDict['Name'][key].lower()] = [pokeDict['Types'][key], pokeDict['Abilities'][key], [pokeDict['HP'][key], pokeDict['Attack'][key], pokeDict['Defense'][key], pokeDict['Special Attack'][key], pokeDict['Special Defense'][key], pokeDict['Speed'][key]], pokeDict['Moves'][key]]

pokeNameDict
# Out:
# {'abomasnow': [['Grass', 'Ice'],
#   ['Snow Warning', 'Soundproof'],
#   [90, 92, 75, 92, 85, 60],
#   ['Ice Punch',
#    'Powder Snow',
#    'Leer',
#    'Razor Leaf',
#    'Icy Wind',
#    'Razor Leaf',
#    'Icy Wind',
#    'Grass Whistle',
#    'Swagger',
#    'Mist',
#    'Ice Shard',
#    'Ingrain',
#    'Wood Hammer',
#    'Blizzard',
#    'Sheer Cold',
#    'Avalanche',
#    'Bullet Seed',
#    "Double'Edge",
#    'Growth',
#    'Leech Seed',
#    'Magical Leaf',
#    'Mist',
#    'Natural Gift',
#    'Seed Bomb',
#    'Skull Bash',
#    'Stomp',
#    'Block',
#    'Focus Punch',
#    'Giga Drain',
#    'Headbutt',
#    'Ice Punch',
#    'Icy Wind',
#    'Iron Tail',
#    "Mud'Slap",
#    'Outrage',
#    'Role Play',
#    'Seed Bomb',
#    'Sleep Talk',
#    'Snore',
#    'Synthesis',
#    'Water Pulse',
#    'Worry Seed',
#    'Focus Punch',
#    'Water Pulse',
#    'Toxic',
#    'Hail',
#    'Bullet Seed',
#    'Hidden Power',
#    'Ice Beam',
#    'Blizzard',
#    'Hyper Beam',
#    'Light Screen',
#    'Protect',
#    'Rain Dance',
#    'Giga Drain',
#    'Safeguard',
#    'Frustration',
#    'Solar Beam',
#    'Iron Tail',
#    'Earthquake',
#    'Return',
#    'Shadow Ball',
#    'Brick Break',
#    'Double Team',
#    'Rock Tomb',
#    'Facade',
#    'Secret Power',
#    'Rest',
#    'Attract',
#    'Round',
#    'Focus Blast',
#    'Energy Ball',
#    'Fling',
#    'Endure',
#    'Giga Impact',
#    'Flash',
#    'Avalanche',
#    'Swords Dance',
#    'Bulldoze',
#    'Frost Breath',
#    'Captivate',
#    'Rock Slide',
#    'Sleep Talk',
#    'Natural Gift',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    'Confide',
#    'Strength',
#    'Rock Smash',
#    'Rock Climb']],
#  'abomasnow-mega': [['Grass', 'Ice'],
#   ['Snow Warning'],
#   [90, 132, 105, 132, 105, 30],
#   ['Ice Punch',
#    'Powder Snow',
#    'Leer',
#    'Razor Leaf',
#    'Icy Wind',
#    'Razor Leaf',
#    'Icy Wind',
#    'Grass Whistle',
#    'Swagger',
#    'Mist',
#    'Ice Shard',
#    'Ingrain',
#    'Wood Hammer',
#    'Blizzard',
#    'Sheer Cold',
#    'Avalanche',
#    'Bullet Seed',
#    "Double'Edge",
#    'Growth',
#    'Leech Seed',
#    'Magical Leaf',
#    'Mist',
#    'Natural Gift',
#    'Seed Bomb',
#    'Skull Bash',
#    'Stomp',
#    'Block',
#    'Focus Punch',
#    'Giga Drain',
#    'Headbutt',
#    'Ice Punch',
#    'Icy Wind',
#    'Iron Tail',
#    "Mud'Slap",
#    'Outrage',
#    'Role Play',
#    'Seed Bomb',
#    'Sleep Talk',
#    'Snore',
#    'Synthesis',
#    'Water Pulse',
#    'Worry Seed',
#    'Focus Punch',
#    'Water Pulse',
#    'Toxic',
#    'Hail',
#    'Bullet Seed',
#    'Hidden Power',
#    'Ice Beam',
#    'Blizzard',
#    'Hyper Beam',
#    'Light Screen',
#    'Protect',
#    'Rain Dance',
#    'Giga Drain',
#    'Safeguard',
#    'Frustration',
#    'Solar Beam',
#    'Iron Tail',
#    'Earthquake',
#    'Return',
#    'Shadow Ball',
#    'Brick Break',
#    'Double Team',
#    'Rock Tomb',
#    'Facade',
#    'Secret Power',
#    'Rest',
#    'Attract',
#    'Round',
#    'Focus Blast',
#    'Energy Ball',
#    'Fling',
#    'Endure',
#    'Giga Impact',
#    'Flash',
#    'Avalanche',
#    'Swords Dance',
#    'Bulldoze',
#    'Frost Breath',
#    'Captivate',
#    'Rock Slide',
#    'Sleep Talk',
#    'Natural Gift',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    'Confide',
#    'Strength',
#    'Rock Smash',
#    'Rock Climb']],
#  'abra': [['Psychic'],
#   ['Inner Focus', 'Magic Guard', 'Synchronize'],
#   [25, 20, 15, 105, 55, 90],
#   ['Teleport',
#    'Ally Switch',
#    'Barrier',
#    'Encore',
#    'Fire Punch',
#    'Guard Split',
#    'Guard Swap',
#    'Ice Punch',
#    'Knock Off',
#    'Light Screen',
#    'Power Trick',
#    'Psychic Terrain',
#    'Psycho Shift',
#    'Skill Swap',
#    'Thunder Punch',
#    'Body Slam',
#    'Counter',
#    "Double'Edge",
#    'Drain Punch',
#    'Dream Eater',
#    'Dynamic Punch',
#    'Endure',
#    'Fire Punch',
#    'Focus Punch',
#    'Foul Play',
#    'Gravity',
#    'Headbutt',
#    'Ice Punch',
#    'Iron Tail',
#    'Knock Off',
#    'Magic Coat',
#    'Magic Room',
#    'Mega Kick',
#    'Mega Punch',
#    'Metronome',
#    'Mimic',
#    'Nightmare',
#    'Psych Up',
#    'Recycle',
#    'Role Play',
#    'Seismic Toss',
#    'Shock Wave',
#    'Signal Beam',
#    'Skill Swap',
#    'Sleep Talk',
#    'Snatch',
#    'Snore',
#    'Substitute',
#    'Swagger',
#    'Thunder Punch',
#    'Thunder Wave',
#    'Trick',
#    'Wonder Room',
#    'Zen Headbutt',
#    'Psyshock',
#    'Focus Punch',
#    'Calm Mind',
#    'Dynamic Punch',
#    'Headbutt',
#    'Curse',
#    'Mega Punch',
#    'Mega Kick',
#    'Toxic',
#    'Body Slam',
#    'Take Down',
#    "Double'Edge",
#    'Submission',
#    'Counter',
#    'Seismic Toss',
#    'Rage',
#    'Zap Cannon',
#    'Psych Up',
#    'Hidden Power',
#    'Sunny Day',
#    'Snore',
#    'Taunt',
#    'Light Screen',
#    'Protect',
#    'Rain Dance',
#    'Endure',
#    'Telekinesis',
#    'Safeguard',
#    'Frustration',
#    'Iron Tail',
#    'Return',
#    'Psychic',
#    'Shadow Ball',
#    'Teleport',
#    'Mimic',
#    'Double Team',
#    'Ice Punch',
#    'Swagger',
#    'Sleep Talk',
#    'Thunder Punch',
#    'Dream Eater',
#    'Reflect',
#    'Shock Wave',
#    'Torment',
#    'Facade',
#    'Secret Power',
#    'Bide',
#    'Metronome',
#    'Skull Bash',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Round',
#    'Ally Switch',
#    'Skill Swap',
#    'Snatch',
#    'Energy Ball',
#    'Fling',
#    'Charge Beam',
#    'Endure',
#    'Drain Punch',
#    'Embargo',
#    'Recycle',
#    'Flash',
#    'Fire Punch',
#    'Nightmare',
#    'Thunder Wave',
#    'Psych Up',
#    'Captivate',
#    'Sleep Talk',
#    'Natural Gift',
#    'Dream Eater',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    'Psywave',
#    'Tri Attack',
#    'Substitute',
#    'Flash',
#    'Trick Room',
#    'Secret Power',
#    'Dazzling Gleam',
#    'Confide']],
#  'absol': [['Dark'],
#   ['Justified', 'Pressure', 'Super Luck'],
#   [65, 130, 60, 75, 60, 75],
#   ['Perish Song',
#    'Future Sight',
#    'Me First',
#    'Razor Wind',
#    'Detect',
#    'Scratch',
#    'Feint',
#    'Leer',
#    'Quick Attack',
#    'Taunt',
#    'Scratch',
#    'Feint',
#    'Leer',
#    'Quick Attack',
#    'Razor Wind',
#    'Pursuit',
#    'Taunt',
#    'Bite',
#    'Double Team',
#    'Slash',
#    'Swords Dance',
#    'Night Slash',
#    'Detect',
#    'Psycho Cut',
#    'Me First',
#    'Bite',
#    'Double Team',
#    'Slash',
#    'Future Sight',
#    'Sucker Punch',
#    'Razor Wind',
#    'Future Sight',
#    'Night Slash',
#    'Detect',
#    'Night Slash',
#    'Me First',
#    'Psycho Cut',
#    'Sucker Punch',
#    'Razor Wind',
#    'Me First',
#    'Perish Song',
#    'Assurance',
#    'Baton Pass',
#    'Curse',
#    "Double'Edge",
#    'Feint Attack',
#    'Hex',
#    'Magic Coat',
#    'Me First',
#    'Mean Look',
#    'Megahorn',
#    'Perish Song',
#    'Play Rough',
#    'Punishment',
#    'Substitute',
#    'Sucker Punch',
#    'Zen Headbutt',
#    'Body Slam',
#    'Bounce',
#    'Counter',
#    'Dark Pulse',
#    "Double'Edge",
#    'Dream Eater',
#    'Endure',
#    'Foul Play',
#    'Fury Cutter',
#    'Headbutt',
#    'Icy Wind',
#    'Iron Tail',
#    'Knock Off',
#    'Magic Coat',
#    'Mimic',
#    "Mud'Slap",
#    'Nightmare',
#    'Psych Up',
#    'Rock Slide',
#    'Role Play',
#    'Shock Wave',
#    'Sleep Talk',
#    'Snatch',
#    'Snore',
#    'Spite',
#    'Substitute',
#    'Sucker Punch',
#    'Superpower',
#    'Swagger',
#    'Swift',
#    'Swords Dance',
#    'Thunder Wave',
#    'Water Pulse',
#    'Zen Headbutt',
#    'Water Pulse',
#    'Hone Claws',
#    'Calm Mind',
#    'Toxic',
#    'Hail',
#    'Hidden Power',
#    'Sunny Day',
#    'Taunt',
#    'Ice Beam',
#    'Blizzard',
#    'Hyper Beam',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Iron Tail',
#    'Thunderbolt',
#    'Thunder',
#    'Return',
#    'Shadow Ball',
#    'Double Team',
#    'Shock Wave',
#    'Flamethrower',
#    'Sandstorm',
#    'Fire Blast',
#    'Rock Tomb',
#    'Aerial Ace',
#    'Torment',
#    'Facade',
#    'Secret Power',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Snatch',
#    'Round',
#    'Echoed Voice',
#    'False Swipe',
#    'Charge Beam',
#    'Brutal Swing',
#    'Incinerate',
#    'Endure',
#    "Will'O'Wisp",
#    'Shadow Claw',
#    'Payback',
#    'Retaliate',
#    'Giga Impact',
#    'Flash',
#    'Stone Edge',
#    'Thunder Wave',
#    'Swords Dance',
#    'Psych Up',
#    'Captivate',
#    'Dark Pulse',
#    'Rock Slide',
#    "X'Scissor",
#    'Sleep Talk',
#    'Natural Gift',
#    'Dream Eater',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    'Snarl',
#    'Dark Pulse',
#    'Confide',
#    'Cut',
#    'Strength',
#    'Flash',
#    'Rock Smash']],
#  'absol-mega': [['Dark'],
#   ['Magic Bounce'],
#   [65, 150, 60, 115, 60, 115],
#   ['Perish Song',
#    'Future Sight',
#    'Me First',
#    'Razor Wind',
#    'Detect',
#    'Scratch',
#    'Feint',
#    'Leer',
#    'Quick Attack',
#    'Taunt',
#    'Scratch',
#    'Feint',
#    'Leer',
#    'Quick Attack',
#    'Razor Wind',
#    'Pursuit',
#    'Taunt',
#    'Bite',
#    'Double Team',
#    'Slash',
#    'Swords Dance',
#    'Night Slash',
#    'Detect',
#    'Psycho Cut',
#    'Me First',
#    'Bite',
#    'Double Team',
#    'Slash',
#    'Future Sight',
#    'Sucker Punch',
#    'Razor Wind',
#    'Future Sight',
#    'Night Slash',
#    'Detect',
#    'Night Slash',
#    'Me First',
#    'Psycho Cut',
#    'Sucker Punch',
#    'Razor Wind',
#    'Me First',
#    'Perish Song',
#    'Assurance',
#    'Baton Pass',
#    'Curse',
#    "Double'Edge",
#    'Feint Attack',
#    'Hex',
#    'Magic Coat',
#    'Me First',
#    'Mean Look',
#    'Megahorn',
#    'Perish Song',
#    'Play Rough',
#    'Punishment',
#    'Substitute',
#    'Sucker Punch',
#    'Zen Headbutt',
#    'Body Slam',
#    'Bounce',
#    'Counter',
#    'Dark Pulse',
#    "Double'Edge",
#    'Dream Eater',
#    'Endure',
#    'Foul Play',
#    'Fury Cutter',
#    'Headbutt',
#    'Icy Wind',
#    'Iron Tail',
#    'Knock Off',
#    'Magic Coat',
#    'Mimic',
#    "Mud'Slap",
#    'Nightmare',
#    'Psych Up',
#    'Rock Slide',
#    'Role Play',
#    'Shock Wave',
#    'Sleep Talk',
#    'Snatch',
#    'Snore',
#    'Spite',
#    'Substitute',
#    'Sucker Punch',
#    'Superpower',
#    'Swagger',
#    'Swift',
#    'Swords Dance',
#    'Thunder Wave',
#    'Water Pulse',
#    'Zen Headbutt',
#    'Water Pulse',
#    'Hone Claws',
#    'Calm Mind',
#    'Toxic',
#    'Hail',
#    'Hidden Power',
#    'Sunny Day',
#    'Taunt',
#    'Ice Beam',
#    'Blizzard',
#    'Hyper Beam',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Iron Tail',
#    'Thunderbolt',
#    'Thunder',
#    'Return',
#    'Shadow Ball',
#    'Double Team',
#    'Shock Wave',
#    'Flamethrower',
#    'Sandstorm',
#    'Fire Blast',
#    'Rock Tomb',
#    'Aerial Ace',
#    'Torment',
#    'Facade',
#    'Secret Power',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Snatch',
#    'Round',
#    'Echoed Voice',
#    'False Swipe',
#    'Charge Beam',
#    'Brutal Swing',
#    'Incinerate',
#    'Endure',
#    "Will'O'Wisp",
#    'Shadow Claw',
#    'Payback',
#    'Retaliate',
#    'Giga Impact',
#    'Flash',
#    'Stone Edge',
#    'Thunder Wave',
#    'Swords Dance',
#    'Psych Up',
#    'Captivate',
#    'Dark Pulse',
#    'Rock Slide',
#    "X'Scissor",
#    'Sleep Talk',
#    'Natural Gift',
#    'Dream Eater',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    'Snarl',
#    'Dark Pulse',
#    'Confide',
#    'Cut',
#    'Strength',
#    'Flash',
#    'Rock Smash']],
#  'accelgor': [['Bug'],
#   ['Hydration', 'Sticky Hold', 'Unburden'],
#   [80, 70, 40, 100, 60, 145],
#   ['Water Shuriken',
#    'Final Gambit',
#    'Power Swap',
#    'Absorb',
#    'Leech Life',
#    'Acid Spray',
#    'Double Team',
#    'Quick Attack',
#    'Acid Spray',
#    'Double Team',
#    'Quick Attack',
#    'Struggle Bug',
#    'Mega Drain',
#    'Swift',
#    'Me First',
#    'Agility',
#    'Giga Drain',
#    "U'turn",
#    'Bug Buzz',
#    'Recover',
#    'Power Swap',
#    'Final Gambit',
#    'Acid',
#    'Bide',
#    'Curse',
#    'Yawn',
#    'Protect',
#    'Acid Armor',
#    'Body Slam',
#    'Guard Swap',
#    'Baton Pass',
#    "Double'Edge",
#    'Encore',
#    'Endure',
#    'Feint',
#    'Guard Split',
#    'Mind Reader',
#    "Mud'Slap",
#    'Pursuit',
#    'Spikes',
#    'Toxic Spikes',
#    'Bug Bite',
#    'Gastro Acid',
#    'Giga Drain',
#    'Knock Off',
#    'Signal Beam',
#    'Sleep Talk',
#    'Snore',
#    'Toxic',
#    'Venoshock',
#    'Hidden Power',
#    'Hyper Beam',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Return',
#    'Leech Life',
#    'Double Team',
#    'Sludge Bomb',
#    'Sandstorm',
#    'Facade',
#    'Rest',
#    'Attract',
#    'Round',
#    'Focus Blast',
#    'Energy Ball',
#    'Giga Impact',
#    'Struggle Bug',
#    'Infestation',
#    'Swagger',
#    'Sleep Talk',
#    "U'turn",
#    'Substitute',
#    'Secret Power',
#    'Confide']],
#  'aegislash': [['Steel', 'Ghost'],
#   ['Stance Change'],
#   [60, 50, 150, 50, 150, 60],
#   ['Fury Cutter',
#    'Pursuit',
#    'Autotomize',
#    'Shadow Sneak',
#    'Slash',
#    'Iron Defense',
#    'Night Slash',
#    'Power Trick',
#    'Iron Head',
#    'Head Smash',
#    'Swords Dance',
#    'Aerial Ace',
#    "King's Shield",
#    'Sacred Sword',
#    'Tackle',
#    'Metal Sound',
#    'Retaliate',
#    'Destiny Bond',
#    'Metal Sound',
#    'Shadow Sneak',
#    'Wide Guard',
#    'After You',
#    'Block',
#    'Iron Defense',
#    'Iron Head',
#    'Magnet Rise',
#    'Shock Wave',
#    'Snore',
#    'Spite',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Hyper Beam',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Return',
#    'Shadow Ball',
#    'Brick Break',
#    'Double Team',
#    'Reflect',
#    'Aerial Ace',
#    'Facade',
#    'Rest',
#    'Attract',
#    'Round',
#    'False Swipe',
#    'Brutal Swing',
#    'Shadow Claw',
#    'Retaliate',
#    'Giga Impact',
#    'Gyro Ball',
#    'Swords Dance',
#    'Rock Slide',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Flash Cannon',
#    'Secret Power',
#    'Rock Smash',
#    'Confide',
#    'Cut',
#    'Rock Smash']],
#  'aegislash-blade': [['Steel', 'Ghost'],
#   ['Stance Change'],
#   [60, 150, 50, 150, 50, 60],
#   ['Fury Cutter',
#    'Pursuit',
#    'Autotomize',
#    'Shadow Sneak',
#    'Slash',
#    'Iron Defense',
#    'Night Slash',
#    'Power Trick',
#    'Iron Head',
#    'Head Smash',
#    'Swords Dance',
#    'Aerial Ace',
#    "King's Shield",
#    'Sacred Sword',
#    'Tackle',
#    'Metal Sound',
#    'Retaliate',
#    'Destiny Bond',
#    'Metal Sound',
#    'Shadow Sneak',
#    'Wide Guard',
#    'After You',
#    'Block',
#    'Iron Defense',
#    'Iron Head',
#    'Magnet Rise',
#    'Shock Wave',
#    'Snore',
#    'Spite',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Hyper Beam',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Return',
#    'Shadow Ball',
#    'Brick Break',
#    'Double Team',
#    'Reflect',
#    'Aerial Ace',
#    'Facade',
#    'Rest',
#    'Attract',
#    'Round',
#    'False Swipe',
#    'Brutal Swing',
#    'Shadow Claw',
#    'Retaliate',
#    'Giga Impact',
#    'Gyro Ball',
#    'Swords Dance',
#    'Rock Slide',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Flash Cannon',
#    'Secret Power',
#    'Rock Smash',
#    'Confide',
#    'Cut',
#    'Rock Smash']],
#  'aerodactyl': [['Rock', 'Flying'],
#   ['Pressure', 'Rock Head', 'Unnerve'],
#   [80, 105, 65, 60, 75, 130],
#   ['Iron Head',
#    'Ice Fang',
#    'Fire Fang',
#    'Thunder Fang',
#    'Wing Attack',
#    'Supersonic',
#    'Bite',
#    'Scary Face',
#    'Roar',
#    'Agility',
#    'Bite',
#    'Supersonic',
#    'Bite',
#    'Ancient Power',
#    'Scary Face',
#    'Crunch',
#    'Take Down',
#    'Iron Head',
#    'Sky Drop',
#    'Iron Head',
#    'Hyper Beam',
#    'Rock Slide',
#    'Giga Impact',
#    'Assurance',
#    'Curse',
#    'Dragon Breath',
#    'Foresight',
#    'Pursuit',
#    'Roost',
#    'Steel Wing',
#    'Tailwind',
#    'Whirlwind',
#    'Wide Guard',
#    'Air Cutter',
#    'Ancient Power',
#    'Aqua Tail',
#    "Double'Edge",
#    'Dragon Pulse',
#    'Earth Power',
#    'Endure',
#    'Flamethrower',
#    'Headbutt',
#    'Heat Wave',
#    'Iron Head',
#    'Iron Tail',
#    'Mimic',
#    'Ominous Wind',
#    'Rock Slide',
#    'Roost',
#    'Sky Attack',
#    'Sleep Talk',
#    'Snore',
#    'Stealth Rock',
#    'Substitute',
#    'Swagger',
#    'Swift',
#    'Tailwind',
#    'Twister',
#    'Headbutt',
#    'Curse',
#    'Razor Wind',
#    'Whirlwind',
#    'Hone Claws',
#    'Dragon Claw',
#    'Roar',
#    'Toxic',
#    'Take Down',
#    "Double'Edge",
#    'Rock Smash',
#    'Hidden Power',
#    'Snore',
#    'Sunny Day',
#    'Taunt',
#    'Hyper Beam',
#    'Rage',
#    'Dragon Rage',
#    'Mimic',
#    'Protect',
#    'Rain Dance',
#    'Endure',
#    'Roost',
#    'Frustration',
#    'Smack Down',
#    'Iron Tail',
#    'Dragon Breath',
#    'Earthquake',
#    'Return',
#    'Double Team',
#    'Flamethrower',
#    'Swagger',
#    'Sleep Talk',
#    'Sandstorm',
#    'Reflect',
#    'Bide',
#    'Fire Blast',
#    'Rock Tomb',
#    'Aerial Ace',
#    'Torment',
#    'Facade',
#    'Secret Power',
#    'Swift',
#    'Detect',
#    'Sky Attack',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Round',
#    'Steel Wing',
#    'Roost',
#    'Sky Drop',
#    'Brutal Swing',
#    'Incinerate',
#    'Endure',
#    'Dragon Pulse',
#    'Payback',
#    'Giga Impact',
#    'Rock Polish',
#    'Stone Edge',
#    'Fly',
#    'Stealth Rock',
#    'Bulldoze',
#    'Captivate',
#    'Rock Slide',
#    'Sleep Talk',
#    'Natural Gift',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    'Confide',
#    'Fly',
#    'Strength',
#    'Defog',
#    'Rock Smash']],
#  'aerodactyl-mega': [['Rock', 'Flying'],
#   ['Tough Claws'],
#   [80, 135, 85, 70, 95, 150],
#   ['Iron Head',
#    'Ice Fang',
#    'Fire Fang',
#    'Thunder Fang',
#    'Wing Attack',
#    'Supersonic',
#    'Bite',
#    'Scary Face',
#    'Roar',
#    'Agility',
#    'Bite',
#    'Supersonic',
#    'Bite',
#    'Ancient Power',
#    'Scary Face',
#    'Crunch',
#    'Take Down',
#    'Iron Head',
#    'Sky Drop',
#    'Iron Head',
#    'Hyper Beam',
#    'Rock Slide',
#    'Giga Impact',
#    'Assurance',
#    'Curse',
#    'Dragon Breath',
#    'Foresight',
#    'Pursuit',
#    'Roost',
#    'Steel Wing',
#    'Tailwind',
#    'Whirlwind',
#    'Wide Guard',
#    'Air Cutter',
#    'Ancient Power',
#    'Aqua Tail',
#    "Double'Edge",
#    'Dragon Pulse',
#    'Earth Power',
#    'Endure',
#    'Flamethrower',
#    'Headbutt',
#    'Heat Wave',
#    'Iron Head',
#    'Iron Tail',
#    'Mimic',
#    'Ominous Wind',
#    'Rock Slide',
#    'Roost',
#    'Sky Attack',
#    'Sleep Talk',
#    'Snore',
#    'Stealth Rock',
#    'Substitute',
#    'Swagger',
#    'Swift',
#    'Tailwind',
#    'Twister',
#    'Headbutt',
#    'Curse',
#    'Razor Wind',
#    'Whirlwind',
#    'Hone Claws',
#    'Dragon Claw',
#    'Roar',
#    'Toxic',
#    'Take Down',
#    "Double'Edge",
#    'Rock Smash',
#    'Hidden Power',
#    'Snore',
#    'Sunny Day',
#    'Taunt',
#    'Hyper Beam',
#    'Rage',
#    'Dragon Rage',
#    'Mimic',
#    'Protect',
#    'Rain Dance',
#    'Endure',
#    'Roost',
#    'Frustration',
#    'Smack Down',
#    'Iron Tail',
#    'Dragon Breath',
#    'Earthquake',
#    'Return',
#    'Double Team',
#    'Flamethrower',
#    'Swagger',
#    'Sleep Talk',
#    'Sandstorm',
#    'Reflect',
#    'Bide',
#    'Fire Blast',
#    'Rock Tomb',
#    'Aerial Ace',
#    'Torment',
#    'Facade',
#    'Secret Power',
#    'Swift',
#    'Detect',
#    'Sky Attack',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Round',
#    'Steel Wing',
#    'Roost',
#    'Sky Drop',
#    'Brutal Swing',
#    'Incinerate',
#    'Endure',
#    'Dragon Pulse',
#    'Payback',
#    'Giga Impact',
#    'Rock Polish',
#    'Stone Edge',
#    'Fly',
#    'Stealth Rock',
#    'Bulldoze',
#    'Captivate',
#    'Rock Slide',
#    'Sleep Talk',
#    'Natural Gift',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    'Confide',
#    'Fly',
#    'Strength',
#    'Defog',
#    'Rock Smash']],
#  'aggron': [['Rock', 'Steel'],
#   ['Heavy Metal', 'Rock Head', 'Sturdy'],
#   [70, 110, 180, 60, 60, 50],
#   ['Tackle',
#    'Harden',
#    "Mud'Slap",
#    'Headbutt',
#    'Harden',
#    "Mud'Slap",
#    'Headbutt',
#    'Metal Claw',
#    'Iron Defense',
#    'Rock Tomb',
#    'Protect',
#    'Roar',
#    'Take Down',
#    'Iron Head',
#    'Protect',
#    'Rock Slide',
#    'Take Down',
#    'Metal Sound',
#    'Iron Tail',
#    'Iron Defense',
#    "Double'Edge",
#    'Protect',
#    'Autotomize',
#    'Heavy Slam',
#    'Metal Sound',
#    "Double'Edge",
#    'Metal Burst',
#    'Body Slam',
#    'Curse',
#    'Dragon Rush',
#    'Endeavor',
#    'Head Smash',
#    'Iron Head',
#    'Reversal',
#    'Screech',
#    'Smelling Salts',
#    'Stealth Rock',
#    'Stomp',
#    'Superpower',
#    'Ancient Power',
#    'Aqua Tail',
#    'Block',
#    'Body Slam',
#    'Counter',
#    'Dark Pulse',
#    'Defense Curl',
#    "Double'Edge",
#    'Dragon Pulse',
#    'Dynamic Punch',
#    'Earth Power',
#    'Endeavor',
#    'Endure',
#    'Fire Punch',
#    'Focus Punch',
#    'Fury Cutter',
#    'Headbutt',
#    'Ice Punch',
#    'Icy Wind',
#    'Iron Defense',
#    'Iron Head',
#    'Iron Tail',
#    'Low Kick',
#    'Magnet Rise',
#    'Mega Kick',
#    'Mega Punch',
#    'Mimic',
#    "Mud'Slap",
#    'Outrage',
#    'Rock Slide',
#    'Rollout',
#    'Seismic Toss',
#    'Shock Wave',
#    'Sleep Talk',
#    'Snore',
#    'Spite',
#    'Stealth Rock',
#    'Substitute',
#    'Superpower',
#    'Swagger',
#    'Thunder Punch',
#    'Thunder Wave',
#    'Uproar',
#    'Water Pulse',
#    'Hone Claws',
#    'Focus Punch',
#    'Dragon Claw',
#    'Water Pulse',
#    'Roar',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Taunt',
#    'Ice Beam',
#    'Blizzard',
#    'Hyper Beam',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Solar Beam',
#    'Smack Down',
#    'Iron Tail',
#    'Thunderbolt',
#    'Thunder',
#    'Earthquake',
#    'Return',
#    'Dig',
#    'Brick Break',
#    'Double Team',
#    'Shock Wave',
#    'Flamethrower',
#    'Sandstorm',
#    'Fire Blast',
#    'Rock Tomb',
#    'Aerial Ace',
#    'Facade',
#    'Secret Power',
#    'Rest',
#    'Attract',
#    'Round',
#    'Focus Blast',
#    'Fling',
#    'Brutal Swing',
#    'Incinerate',
#    'Endure',
#    'Dragon Pulse',
#    'Shadow Claw',
#    'Payback',
#    'Smart Strike',
#    'Giga Impact',
#    'Rock Polish',
#    'Stone Edge',
#    'Avalanche',
#    'Thunder Wave',
#    'Bulldoze',
#    'Stealth Rock',
#    'Captivate',
#    'Dark Pulse',
#    'Rock Slide',
#    'Dragon Tail',
#    'Sleep Talk',
#    'Natural Gift',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Flash Cannon',
#    'Surf',
#    'Secret Power',
#    'Rock Smash',
#    'Dark Pulse',
#    "Power'Up Punch",
#    'Confide',
#    'Cut',
#    'Surf',
#    'Strength',
#    'Whirlpool',
#    'Rock Smash',
#    'Rock Climb']],
#  'aggron-mega': [['Steel'],
#   ['Filter'],
#   [70, 140, 230, 60, 80, 50],
#   ['Tackle',
#    'Harden',
#    "Mud'Slap",
#    'Headbutt',
#    'Harden',
#    "Mud'Slap",
#    'Headbutt',
#    'Metal Claw',
#    'Iron Defense',
#    'Rock Tomb',
#    'Protect',
#    'Roar',
#    'Take Down',
#    'Iron Head',
#    'Protect',
#    'Rock Slide',
#    'Take Down',
#    'Metal Sound',
#    'Iron Tail',
#    'Iron Defense',
#    "Double'Edge",
#    'Protect',
#    'Autotomize',
#    'Heavy Slam',
#    'Metal Sound',
#    "Double'Edge",
#    'Metal Burst',
#    'Body Slam',
#    'Curse',
#    'Dragon Rush',
#    'Endeavor',
#    'Head Smash',
#    'Iron Head',
#    'Reversal',
#    'Screech',
#    'Smelling Salts',
#    'Stealth Rock',
#    'Stomp',
#    'Superpower',
#    'Ancient Power',
#    'Aqua Tail',
#    'Block',
#    'Body Slam',
#    'Counter',
#    'Dark Pulse',
#    'Defense Curl',
#    "Double'Edge",
#    'Dragon Pulse',
#    'Dynamic Punch',
#    'Earth Power',
#    'Endeavor',
#    'Endure',
#    'Fire Punch',
#    'Focus Punch',
#    'Fury Cutter',
#    'Headbutt',
#    'Ice Punch',
#    'Icy Wind',
#    'Iron Defense',
#    'Iron Head',
#    'Iron Tail',
#    'Low Kick',
#    'Magnet Rise',
#    'Mega Kick',
#    'Mega Punch',
#    'Mimic',
#    "Mud'Slap",
#    'Outrage',
#    'Rock Slide',
#    'Rollout',
#    'Seismic Toss',
#    'Shock Wave',
#    'Sleep Talk',
#    'Snore',
#    'Spite',
#    'Stealth Rock',
#    'Substitute',
#    'Superpower',
#    'Swagger',
#    'Thunder Punch',
#    'Thunder Wave',
#    'Uproar',
#    'Water Pulse',
#    'Hone Claws',
#    'Focus Punch',
#    'Dragon Claw',
#    'Water Pulse',
#    'Roar',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Taunt',
#    'Ice Beam',
#    'Blizzard',
#    'Hyper Beam',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Solar Beam',
#    'Smack Down',
#    'Iron Tail',
#    'Thunderbolt',
#    'Thunder',
#    'Earthquake',
#    'Return',
#    'Dig',
#    'Brick Break',
#    'Double Team',
#    'Shock Wave',
#    'Flamethrower',
#    'Sandstorm',
#    'Fire Blast',
#    'Rock Tomb',
#    'Aerial Ace',
#    'Facade',
#    'Secret Power',
#    'Rest',
#    'Attract',
#    'Round',
#    'Focus Blast',
#    'Fling',
#    'Brutal Swing',
#    'Incinerate',
#    'Endure',
#    'Dragon Pulse',
#    'Shadow Claw',
#    'Payback',
#    'Smart Strike',
#    'Giga Impact',
#    'Rock Polish',
#    'Stone Edge',
#    'Avalanche',
#    'Thunder Wave',
#    'Bulldoze',
#    'Stealth Rock',
#    'Captivate',
#    'Dark Pulse',
#    'Rock Slide',
#    'Dragon Tail',
#    'Sleep Talk',
#    'Natural Gift',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Flash Cannon',
#    'Surf',
#    'Secret Power',
#    'Rock Smash',
#    'Dark Pulse',
#    "Power'Up Punch",
#    'Confide',
#    'Cut',
#    'Surf',
#    'Strength',
#    'Whirlpool',
#    'Rock Smash',
#    'Rock Climb']],
#  'aipom': [['Normal'],
#   ['Pickup', 'Run Away', 'Skill Link'],
#   [55, 70, 55, 40, 55, 85],
#   ['Scratch',
#    'Tail Whip',
#    'Sand Attack',
#    'Astonish',
#    'Baton Pass',
#    'Tickle',
#    'Fury Swipes',
#    'Swift',
#    'Screech',
#    'Agility',
#    'Double Hit',
#    'Fling',
#    'Nasty Plot',
#    'Last Resort',
#    'Agility',
#    'Beat Up',
#    'Bounce',
#    'Counter',
#    'Covet',
#    'Double Slap',
#    'Fake Out',
#    'Pursuit',
#    'Quick Guard',
#    'Revenge',
#    'Screech',
#    'Slam',
#    'Spite',
#    'Switcheroo',
#    'Tail Slap',
#    'Body Slam',
#    'Bounce',
#    'Counter',
#    'Covet',
#    'Defense Curl',
#    "Double'Edge",
#    'Dream Eater',
#    'Dynamic Punch',
#    'Endure',
#    'Fire Punch',
#    'Focus Punch',
#    'Foul Play',
#    'Fury Cutter',
#    'Gunk Shot',
#    'Headbutt',
#    'Ice Punch',
#    'Iron Tail',
#    'Knock Off',
#    'Last Resort',
#    'Low Kick',
#    'Mega Kick',
#    'Mega Punch',
#    'Metronome',
#    'Mimic',
#    "Mud'Slap",
#    'Nightmare',
#    'Role Play',
#    'Seed Bomb',
#    'Seismic Toss',
#    'Shock Wave',
#    'Sleep Talk',
#    'Snatch',
#    'Snore',
#    'Spite',
#    'Substitute',
#    'Swagger',
#    'Swift',
#    'Thunder Punch',
#    'Thunder Wave',
#    'Thunderbolt',
#    'Uproar',
#    'Water Pulse',
#    'Work Up',
#    'Hone Claws',
#    'Focus Punch',
#    'Water Pulse',
#    'Dynamic Punch',
#    'Headbutt',
#    'Curse',
#    'Toxic',
#    'Zap Cannon',
#    'Rock Smash',
#    'Hidden Power',
#    'Sunny Day',
#    'Snore',
#    'Taunt',
#    'Protect',
#    'Endure',
#    'Rain Dance',
#    'Frustration',
#    'Solar Beam',
#    'Iron Tail',
#    'Thunderbolt',
#    'Thunder',
#    'Return',
#    'Dig',
#    'Shadow Ball',
#    'Brick Break',
#    "Mud'Slap",
#    'Double Team',
#    'Shock Wave',
#    'Aerial Ace',
#    'Facade',
#    'Secret Power',
#    'Ice Punch',
#    'Swagger',
#    'Sleep Talk',
#    'Swift',
#    'Defense Curl',
#    'Thunder Punch',
#    'Dream Eater',
#    'Detect',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Snatch',
#    'Fire Punch',
#    'Fury Cutter',
#    'Nightmare',
#    'Low Sweep',
#    'Round',
#    'Fling',
#    'Acrobatics',
#    'Endure',
#    'Shadow Claw',
#    'Payback',
#    'Retaliate',
#    'Thunder Wave',
#    'Work Up',
#    'Captivate',
#    'Sleep Talk',
#    'Natural Gift',
#    'Dream Eater',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    "U'turn",
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    "Power'Up Punch",
#    'Confide',
#    'Cut',
#    'Strength',
#    'Rock Smash']],
#  'alakazam': [['Psychic'],
#   ['Inner Focus', 'Magic Guard', 'Synchronize'],
#   [55, 50, 45, 135, 95, 120],
#   ['Teleport',
#    'Confusion',
#    'Disable',
#    'Kinesis',
#    'Kinesis',
#    'Teleport',
#    'Confusion',
#    'Confusion',
#    'Disable',
#    'Psybeam',
#    'Reflect',
#    'Recover',
#    'Future Sight',
#    'Miracle Eye',
#    'Psybeam',
#    'Ally Switch',
#    'Psybeam',
#    'Reflect',
#    'Psycho Cut',
#    'Recover',
#    'Psycho Cut',
#    'Telekinesis',
#    'Recover',
#    'Psycho Cut',
#    'Ally Switch',
#    'Calm Mind',
#    'Psychic',
#    'Reflect',
#    'Calm Mind',
#    'Future Sight',
#    'Trick',
#    'Role Play',
#    'Ally Switch',
#    'Barrier',
#    'Encore',
#    'Fire Punch',
#    'Guard Split',
#    'Guard Swap',
#    'Ice Punch',
#    'Knock Off',
#    'Light Screen',
#    'Power Trick',
#    'Psychic Terrain',
#    'Psycho Shift',
#    'Skill Swap',
#    'Thunder Punch',
#    'Body Slam',
#    'Counter',
#    "Double'Edge",
#    'Drain Punch',
#    'Dream Eater',
#    'Dynamic Punch',
#    'Endure',
#    'Fire Punch',
#    'Focus Punch',
#    'Foul Play',
#    'Gravity',
#    'Headbutt',
#    'Ice Punch',
#    'Iron Tail',
#    'Knock Off',
#    'Magic Coat',
#    'Magic Room',
#    'Mega Kick',
#    'Mega Punch',
#    'Metronome',
#    'Mimic',
#    'Nightmare',
#    'Psych Up',
#    'Recycle',
#    'Role Play',
#    'Seismic Toss',
#    'Shock Wave',
#    'Signal Beam',
#    'Skill Swap',
#    'Sleep Talk',
#    'Snatch',
#    'Snore',
#    'Substitute',
#    'Swagger',
#    'Thunder Punch',
#    'Thunder Wave',
#    'Trick',
#    'Wonder Room',
#    'Zen Headbutt',
#    'Psyshock',
#    'Focus Punch',
#    'Calm Mind',
#    'Dynamic Punch',
#    'Headbutt',
#    'Curse',
#    'Mega Punch',
#    'Mega Kick',
#    'Toxic',
#    'Body Slam',
#    'Take Down',
#    "Double'Edge",
#    'Zap Cannon',
#    'Psych Up',
#    'Hidden Power',
#    'Sunny Day',
#    'Snore',
#    'Taunt',
#    'Hyper Beam',
#    'Submission',
#    'Counter',
#    'Seismic Toss',
#    'Rage',
#    'Light Screen',
#    'Protect',
#    'Rain Dance',
#    'Endure',
#    'Telekinesis',
#    'Safeguard',
#    'Frustration',
#    'Iron Tail',
#    'Return',
#    'Dig',
#    'Psychic',
#    'Shadow Ball',
#    'Teleport',
#    'Mimic',
#    'Double Team',
#    'Ice Punch',
#    'Swagger',
#    'Sleep Talk',
#    'Thunder Punch',
#    'Dream Eater',
#    'Reflect',
#    'Shock Wave',
#    'Torment',
#    'Facade',
#    'Secret Power',
#    'Bide',
#    'Metronome',
#    'Skull Bash',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Round',
#    'Ally Switch',
#    'Skill Swap',
#    'Snatch',
#    'Focus Blast',
#    'Energy Ball',
#    'Fling',
#    'Charge Beam',
#    'Endure',
#    'Drain Punch',
#    'Embargo',
#    'Recycle',
#    'Giga Impact',
#    'Flash',
#    'Fire Punch',
#    'Nightmare',
#    'Thunder Wave',
#    'Psych Up',
#    'Captivate',
#    'Sleep Talk',
#    'Natural Gift',
#    'Dream Eater',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    'Psywave',
#    'Tri Attack',
#    'Substitute',
#    'Flash',
#    'Trick Room',
#    'Secret Power',
#    'Dazzling Gleam',
#    'Confide']],
#  'alakazam-mega': [['Psychic'],
#   ['Trace'],
#   [55, 50, 65, 175, 105, 150],
#   ['Teleport',
#    'Confusion',
#    'Disable',
#    'Kinesis',
#    'Kinesis',
#    'Teleport',
#    'Confusion',
#    'Confusion',
#    'Disable',
#    'Psybeam',
#    'Reflect',
#    'Recover',
#    'Future Sight',
#    'Miracle Eye',
#    'Psybeam',
#    'Ally Switch',
#    'Psybeam',
#    'Reflect',
#    'Psycho Cut',
#    'Recover',
#    'Psycho Cut',
#    'Telekinesis',
#    'Recover',
#    'Psycho Cut',
#    'Ally Switch',
#    'Calm Mind',
#    'Psychic',
#    'Reflect',
#    'Calm Mind',
#    'Future Sight',
#    'Trick',
#    'Role Play',
#    'Ally Switch',
#    'Barrier',
#    'Encore',
#    'Fire Punch',
#    'Guard Split',
#    'Guard Swap',
#    'Ice Punch',
#    'Knock Off',
#    'Light Screen',
#    'Power Trick',
#    'Psychic Terrain',
#    'Psycho Shift',
#    'Skill Swap',
#    'Thunder Punch',
#    'Body Slam',
#    'Counter',
#    "Double'Edge",
#    'Drain Punch',
#    'Dream Eater',
#    'Dynamic Punch',
#    'Endure',
#    'Fire Punch',
#    'Focus Punch',
#    'Foul Play',
#    'Gravity',
#    'Headbutt',
#    'Ice Punch',
#    'Iron Tail',
#    'Knock Off',
#    'Magic Coat',
#    'Magic Room',
#    'Mega Kick',
#    'Mega Punch',
#    'Metronome',
#    'Mimic',
#    'Nightmare',
#    'Psych Up',
#    'Recycle',
#    'Role Play',
#    'Seismic Toss',
#    'Shock Wave',
#    'Signal Beam',
#    'Skill Swap',
#    'Sleep Talk',
#    'Snatch',
#    'Snore',
#    'Substitute',
#    'Swagger',
#    'Thunder Punch',
#    'Thunder Wave',
#    'Trick',
#    'Wonder Room',
#    'Zen Headbutt',
#    'Psyshock',
#    'Focus Punch',
#    'Calm Mind',
#    'Dynamic Punch',
#    'Headbutt',
#    'Curse',
#    'Mega Punch',
#    'Mega Kick',
#    'Toxic',
#    'Body Slam',
#    'Take Down',
#    "Double'Edge",
#    'Zap Cannon',
#    'Psych Up',
#    'Hidden Power',
#    'Sunny Day',
#    'Snore',
#    'Taunt',
#    'Hyper Beam',
#    'Submission',
#    'Counter',
#    'Seismic Toss',
#    'Rage',
#    'Light Screen',
#    'Protect',
#    'Rain Dance',
#    'Endure',
#    'Telekinesis',
#    'Safeguard',
#    'Frustration',
#    'Iron Tail',
#    'Return',
#    'Dig',
#    'Psychic',
#    'Shadow Ball',
#    'Teleport',
#    'Mimic',
#    'Double Team',
#    'Ice Punch',
#    'Swagger',
#    'Sleep Talk',
#    'Thunder Punch',
#    'Dream Eater',
#    'Reflect',
#    'Shock Wave',
#    'Torment',
#    'Facade',
#    'Secret Power',
#    'Bide',
#    'Metronome',
#    'Skull Bash',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Round',
#    'Ally Switch',
#    'Skill Swap',
#    'Snatch',
#    'Focus Blast',
#    'Energy Ball',
#    'Fling',
#    'Charge Beam',
#    'Endure',
#    'Drain Punch',
#    'Embargo',
#    'Recycle',
#    'Giga Impact',
#    'Flash',
#    'Fire Punch',
#    'Nightmare',
#    'Thunder Wave',
#    'Psych Up',
#    'Captivate',
#    'Sleep Talk',
#    'Natural Gift',
#    'Dream Eater',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    'Psywave',
#    'Tri Attack',
#    'Substitute',
#    'Flash',
#    'Trick Room',
#    'Secret Power',
#    'Dazzling Gleam',
#    'Confide']],
#  'alomomola': [['Water'],
#   ['Healer', 'Hydration', 'Regenerator'],
#   [165, 75, 80, 40, 45, 65],
#   ['Play Nice',
#    'Hydro Pump',
#    'Wide Guard',
#    'Healing Wish',
#    'Helping Hand',
#    'Pound',
#    'Water Sport',
#    'Aqua Ring',
#    'Aqua Jet',
#    'Double Slap',
#    'Heal Pulse',
#    'Protect',
#    'Water Pulse',
#    "Wake'Up Slap",
#    'Soak',
#    'Wish',
#    'Brine',
#    'Safeguard',
#    'Whirlpool',
#    'Helping Hand',
#    'Wide Guard',
#    'Healing Wish',
#    'Wide Guard',
#    'Hydro Pump',
#    'Endure',
#    'Mirror Coat',
#    'Mist',
#    'Pain Split',
#    'Refresh',
#    'Tickle',
#    'Bounce',
#    'Helping Hand',
#    'Icy Wind',
#    'Knock Off',
#    'Magic Coat',
#    'Pain Split',
#    'Sleep Talk',
#    'Snore',
#    'Water Pulse',
#    'Calm Mind',
#    'Toxic',
#    'Hail',
#    'Hidden Power',
#    'Ice Beam',
#    'Blizzard',
#    'Light Screen',
#    'Protect',
#    'Rain Dance',
#    'Safeguard',
#    'Frustration',
#    'Return',
#    'Psychic',
#    'Shadow Ball',
#    'Double Team',
#    'Facade',
#    'Rest',
#    'Attract',
#    'Round',
#    'Scald',
#    'Psych Up',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Surf',
#    'Waterfall',
#    'Secret Power',
#    'Confide',
#    'Surf',
#    'Waterfall',
#    'Dive']],
#  'altaria': [['Dragon', 'Flying'],
#   ['Cloud Nine', 'Natural Cure'],
#   [75, 70, 90, 70, 105, 80],
#   ['Sky Attack',
#    'Peck',
#    'Growl',
#    'Astonish',
#    'Pluck',
#    'Peck',
#    'Growl',
#    'Astonish',
#    'Dragon Breath',
#    'Dragon Breath',
#    'Sky Attack',
#    'Pluck',
#    'Peck',
#    'Growl',
#    'Astonish',
#    'Sing',
#    'Astonish',
#    'Sing',
#    'Fury Attack',
#    'Safeguard',
#    'Disarming Voice',
#    'Mist',
#    'Round',
#    'Natural Gift',
#    'Take Down',
#    'Natural Gift',
#    'Refresh',
#    'Dragon Dance',
#    'Cotton Guard',
#    'Dragon Breath',
#    'Dragon Pulse',
#    'Perish Song',
#    'Moonblast',
#    'Dragon Dance',
#    'Refresh',
#    'Cotton Guard',
#    'Refresh',
#    'Dragon Pulse',
#    'Perish Song',
#    'Moonblast',
#    'Sky Attack',
#    'Mirror Move',
#    'Agility',
#    'Dragon Rush',
#    'Feather Dance',
#    'Haze',
#    'Hyper Voice',
#    'Play Rough',
#    'Power Swap',
#    'Pursuit',
#    'Rage',
#    'Roost',
#    'Steel Wing',
#    'Air Cutter',
#    'Body Slam',
#    "Double'Edge",
#    'Draco Meteor',
#    'Dragon Pulse',
#    'Dream Eater',
#    'Endure',
#    'Heal Bell',
#    'Heat Wave',
#    'Hyper Voice',
#    'Iron Tail',
#    'Mimic',
#    "Mud'Slap",
#    'Ominous Wind',
#    'Outrage',
#    'Psych Up',
#    'Roost',
#    'Sky Attack',
#    'Sleep Talk',
#    'Snore',
#    'Substitute',
#    'Swagger',
#    'Swift',
#    'Tailwind',
#    'Twister',
#    'Uproar',
#    'Wonder Room',
#    'Hone Claws',
#    'Dragon Claw',
#    'Roar',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Ice Beam',
#    'Hyper Beam',
#    'Protect',
#    'Rain Dance',
#    'Roost',
#    'Safeguard',
#    'Frustration',
#    'Solar Beam',
#    'Iron Tail',
#    'Earthquake',
#    'Return',
#    'Double Team',
#    'Flamethrower',
#    'Fire Blast',
#    'Aerial Ace',
#    'Facade',
#    'Secret Power',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Round',
#    'Echoed Voice',
#    'Steel Wing',
#    'Roost',
#    'Incinerate',
#    'Endure',
#    'Dragon Pulse',
#    'Giga Impact',
#    'Fly',
#    'Psych Up',
#    'Bulldoze',
#    'Captivate',
#    'Sleep Talk',
#    'Natural Gift',
#    'Dream Eater',
#    'Swagger',
#    'Sleep Talk',
#    'Pluck',
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    'Dazzling Gleam',
#    'Confide',
#    'Fly',
#    'Rock Smash']],
#  'altaria-mega': [['Dragon', 'Fairy'],
#   ['Pixilate'],
#   [75, 110, 110, 110, 105, 80],
#   ['Sky Attack',
#    'Peck',
#    'Growl',
#    'Astonish',
#    'Pluck',
#    'Peck',
#    'Growl',
#    'Astonish',
#    'Dragon Breath',
#    'Dragon Breath',
#    'Sky Attack',
#    'Pluck',
#    'Peck',
#    'Growl',
#    'Astonish',
#    'Sing',
#    'Astonish',
#    'Sing',
#    'Fury Attack',
#    'Safeguard',
#    'Disarming Voice',
#    'Mist',
#    'Round',
#    'Natural Gift',
#    'Take Down',
#    'Natural Gift',
#    'Refresh',
#    'Dragon Dance',
#    'Cotton Guard',
#    'Dragon Breath',
#    'Dragon Pulse',
#    'Perish Song',
#    'Moonblast',
#    'Dragon Dance',
#    'Refresh',
#    'Cotton Guard',
#    'Refresh',
#    'Dragon Pulse',
#    'Perish Song',
#    'Moonblast',
#    'Sky Attack',
#    'Mirror Move',
#    'Agility',
#    'Dragon Rush',
#    'Feather Dance',
#    'Haze',
#    'Hyper Voice',
#    'Play Rough',
#    'Power Swap',
#    'Pursuit',
#    'Rage',
#    'Roost',
#    'Steel Wing',
#    'Air Cutter',
#    'Body Slam',
#    "Double'Edge",
#    'Draco Meteor',
#    'Dragon Pulse',
#    'Dream Eater',
#    'Endure',
#    'Heal Bell',
#    'Heat Wave',
#    'Hyper Voice',
#    'Iron Tail',
#    'Mimic',
#    "Mud'Slap",
#    'Ominous Wind',
#    'Outrage',
#    'Psych Up',
#    'Roost',
#    'Sky Attack',
#    'Sleep Talk',
#    'Snore',
#    'Substitute',
#    'Swagger',
#    'Swift',
#    'Tailwind',
#    'Twister',
#    'Uproar',
#    'Wonder Room',
#    'Hone Claws',
#    'Dragon Claw',
#    'Roar',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Ice Beam',
#    'Hyper Beam',
#    'Protect',
#    'Rain Dance',
#    'Roost',
#    'Safeguard',
#    'Frustration',
#    'Solar Beam',
#    'Iron Tail',
#    'Earthquake',
#    'Return',
#    'Double Team',
#    'Flamethrower',
#    'Fire Blast',
#    'Aerial Ace',
#    'Facade',
#    'Secret Power',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Round',
#    'Echoed Voice',
#    'Steel Wing',
#    'Roost',
#    'Incinerate',
#    'Endure',
#    'Dragon Pulse',
#    'Giga Impact',
#    'Fly',
#    'Psych Up',
#    'Bulldoze',
#    'Captivate',
#    'Sleep Talk',
#    'Natural Gift',
#    'Dream Eater',
#    'Swagger',
#    'Sleep Talk',
#    'Pluck',
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    'Dazzling Gleam',
#    'Confide',
#    'Fly',
#    'Rock Smash']],
#  'amaura': [['Rock', 'Ice'],
#   ['Refrigerate', 'Snow Warning'],
#   [77, 59, 50, 67, 63, 46],
#   ['Growl',
#    'Powder Snow',
#    'Thunder Wave',
#    'Rock Throw',
#    'Icy Wind',
#    'Take Down',
#    'Mist',
#    'Aurora Beam',
#    'Ancient Power',
#    'Round',
#    'Avalanche',
#    'Hail',
#    'Nature Power',
#    'Encore',
#    'Light Screen',
#    'Ice Beam',
#    'Hyper Beam',
#    'Blizzard',
#    'Barrier',
#    'Discharge',
#    'Haze',
#    'Magnet Rise',
#    'Mirror Coat',
#    'Aqua Tail',
#    'Earth Power',
#    'Hyper Voice',
#    'Icy Wind',
#    'Iron Defense',
#    'Iron Head',
#    'Iron Tail',
#    'Magnet Rise',
#    'Outrage',
#    'Snore',
#    'Stealth Rock',
#    'Water Pulse',
#    'Zen Headbutt',
#    'Calm Mind',
#    'Roar',
#    'Toxic',
#    'Hail',
#    'Hidden Power',
#    'Ice Beam',
#    'Blizzard',
#    'Hyper Beam',
#    'Light Screen',
#    'Protect',
#    'Rain Dance',
#    'Safeguard',
#    'Frustration',
#    'Thunderbolt',
#    'Return',
#    'Double Team',
#    'Reflect',
#    'Sandstorm',
#    'Rock Tomb',
#    'Facade',
#    'Rest',
#    'Attract',
#    'Round',
#    'Echoed Voice',
#    'Charge Beam',
#    'Rock Polish',
#    'Flash',
#    'Stone Edge',
#    'Thunder Wave',
#    'Psych Up',
#    'Bulldoze',
#    'Frost Breath',
#    'Rock Slide',
#    'Dragon Tail',
#    'Dream Eater',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Flash Cannon',
#    'Secret Power',
#    'Rock Smash',
#    'Nature Power',
#    'Dark Pulse',
#    'Confide',
#    'Rock Smash']],
#  'ambipom': [['Normal'],
#   ['Pickup', 'Skill Link', 'Technician'],
#   [75, 100, 66, 60, 66, 115],
#   ['Dual Chop',
#    'Scratch',
#    'Tail Whip',
#    'Sand Attack',
#    'Astonish',
#    'Sand Attack',
#    'Astonish',
#    'Baton Pass',
#    'Tickle',
#    'Fury Swipes',
#    'Swift',
#    'Screech',
#    'Agility',
#    'Double Hit',
#    'Fling',
#    'Nasty Plot',
#    'Last Resort',
#    'Agility',
#    'Beat Up',
#    'Bounce',
#    'Counter',
#    'Covet',
#    'Double Slap',
#    'Fake Out',
#    'Pursuit',
#    'Quick Guard',
#    'Revenge',
#    'Screech',
#    'Slam',
#    'Spite',
#    'Switcheroo',
#    'Tail Slap',
#    'Bounce',
#    'Covet',
#    'Fire Punch',
#    'Focus Punch',
#    'Foul Play',
#    'Fury Cutter',
#    'Gunk Shot',
#    'Headbutt',
#    'Ice Punch',
#    'Iron Tail',
#    'Knock Off',
#    'Last Resort',
#    'Low Kick',
#    "Mud'Slap",
#    'Role Play',
#    'Seed Bomb',
#    'Shock Wave',
#    'Sleep Talk',
#    'Snatch',
#    'Snore',
#    'Spite',
#    'Swift',
#    'Thunder Punch',
#    'Uproar',
#    'Water Pulse',
#    'Work Up',
#    'Hone Claws',
#    'Focus Punch',
#    'Water Pulse',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Taunt',
#    'Hyper Beam',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Solar Beam',
#    'Iron Tail',
#    'Thunderbolt',
#    'Thunder',
#    'Return',
#    'Dig',
#    'Shadow Ball',
#    'Brick Break',
#    'Double Team',
#    'Shock Wave',
#    'Aerial Ace',
#    'Facade',
#    'Secret Power',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Snatch',
#    'Low Sweep',
#    'Round',
#    'Fling',
#    'Acrobatics',
#    'Endure',
#    'Shadow Claw',
#    'Payback',
#    'Retaliate',
#    'Giga Impact',
#    'Thunder Wave',
#    'Work Up',
#    'Captivate',
#    'Sleep Talk',
#    'Natural Gift',
#    'Dream Eater',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    "U'turn",
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    "Power'Up Punch",
#    'Confide',
#    'Cut',
#    'Strength',
#    'Rock Smash']],
#  'amoonguss': [['Grass', 'Poison'],
#   ['Effect Spore', 'Regenerator'],
#   [114, 85, 70, 85, 80, 30],
#   ['Absorb',
#    'Growth',
#    'Astonish',
#    'Bide',
#    'Growth',
#    'Astonish',
#    'Bide',
#    'Mega Drain',
#    'Ingrain',
#    'Feint Attack',
#    'Sweet Scent',
#    'Giga Drain',
#    'Toxic',
#    'Synthesis',
#    'Clear Smog',
#    'Solar Beam',
#    'Rage Powder',
#    'Spore',
#    'Body Slam',
#    'Defense Curl',
#    'Endure',
#    'Gastro Acid',
#    'Growth',
#    'Poison Powder',
#    'Rollout',
#    'Stun Spore',
#    'After You',
#    'Foul Play',
#    'Gastro Acid',
#    'Giga Drain',
#    'Seed Bomb',
#    'Sleep Talk',
#    'Snore',
#    'Synthesis',
#    'Worry Seed',
#    'Toxic',
#    'Venoshock',
#    'Hidden Power',
#    'Sunny Day',
#    'Hyper Beam',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Solar Beam',
#    'Return',
#    'Double Team',
#    'Sludge Bomb',
#    'Facade',
#    'Rest',
#    'Attract',
#    'Round',
#    'Energy Ball',
#    'Payback',
#    'Giga Impact',
#    'Flash',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Secret Power',
#    'Nature Power',
#    'Confide']],
#  'ampharos': [['Electric'],
#   ['Plus', 'Static'],
#   [90, 75, 85, 115, 90, 55],
#   ['Zap Cannon',
#    'Magnetic Flux',
#    'Ion Deluge',
#    'Dragon Pulse',
#    'Fire Punch',
#    'Tackle',
#    'Growl',
#    'Thunder Shock',
#    'Thunder Punch',
#    'Thunder Punch',
#    'Zap Cannon',
#    'Magnetic Flux',
#    'Ion Deluge',
#    'Dragon Pulse',
#    'Fire Punch',
#    'Tackle',
#    'Growl',
#    'Thunder Wave',
#    'Growl',
#    'Thunder Shock',
#    'Thunder Wave',
#    'Thunder Shock',
#    'Cotton Spore',
#    'Charge',
#    'Take Down',
#    'Electro Ball',
#    'Confuse Ray',
#    'Thunder Punch',
#    'Power Gem',
#    'Discharge',
#    'Signal Beam',
#    'Electro Ball',
#    'Cotton Guard',
#    'Discharge',
#    'Signal Beam',
#    'Light Screen',
#    'Power Gem',
#    'Thunder',
#    'Dragon Pulse',
#    'After You',
#    'Agility',
#    'Body Slam',
#    'Charge',
#    'Eerie Impulse',
#    'Electric Terrain',
#    'Flatter',
#    'Iron Tail',
#    'Odor Sleuth',
#    'Reflect',
#    'Safeguard',
#    'Sand Attack',
#    'Screech',
#    'Take Down',
#    'Thunderbolt',
#    'After You',
#    'Body Slam',
#    'Counter',
#    'Defense Curl',
#    "Double'Edge",
#    'Dragon Pulse',
#    'Dynamic Punch',
#    'Electroweb',
#    'Endure',
#    'Fire Punch',
#    'Focus Punch',
#    'Headbutt',
#    'Heal Bell',
#    'Iron Tail',
#    'Magnet Rise',
#    'Mega Kick',
#    'Mega Punch',
#    'Mimic',
#    'Outrage',
#    'Seismic Toss',
#    'Shock Wave',
#    'Signal Beam',
#    'Sleep Talk',
#    'Snore',
#    'Substitute',
#    'Swagger',
#    'Swift',
#    'Thunder Punch',
#    'Thunder Wave',
#    'Thunderbolt',
#    'Focus Punch',
#    'Dynamic Punch',
#    'Headbutt',
#    'Curse',
#    'Toxic',
#    'Zap Cannon',
#    'Rock Smash',
#    'Hidden Power',
#    'Snore',
#    'Hyper Beam',
#    'Light Screen',
#    'Protect',
#    'Rain Dance',
#    'Safeguard',
#    'Endure',
#    'Frustration',
#    'Iron Tail',
#    'Thunderbolt',
#    'Thunder',
#    'Return',
#    'Brick Break',
#    'Double Team',
#    'Shock Wave',
#    'Facade',
#    'Secret Power',
#    'Swagger',
#    'Sleep Talk',
#    'Swift',
#    'Defense Curl',
#    'Thunder Punch',
#    'Rest',
#    'Attract',
#    'Round',
#    'Echoed Voice',
#    'Fire Punch',
#    'Focus Blast',
#    'Fling',
#    'Charge Beam',
#    'Brutal Swing',
#    'Endure',
#    'Giga Impact',
#    'Flash',
#    'Volt Switch',
#    'Thunder Wave',
#    'Bulldoze',
#    'Captivate',
#    'Sleep Talk',
#    'Natural Gift',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Wild Charge',
#    'Secret Power',
#    'Rock Smash',
#    "Power'Up Punch",
#    'Confide',
#    'Strength',
#    'Flash',
#    'Rock Smash',
#    'Rock Climb']],
#  'ampharos-mega': [['Electric', 'Dragon'],
#   ['Mold Breaker'],
#   [90, 95, 105, 165, 110, 45],
#   ['Zap Cannon',
#    'Magnetic Flux',
#    'Ion Deluge',
#    'Dragon Pulse',
#    'Fire Punch',
#    'Tackle',
#    'Growl',
#    'Thunder Shock',
#    'Thunder Punch',
#    'Thunder Punch',
#    'Zap Cannon',
#    'Magnetic Flux',
#    'Ion Deluge',
#    'Dragon Pulse',
#    'Fire Punch',
#    'Tackle',
#    'Growl',
#    'Thunder Wave',
#    'Growl',
#    'Thunder Shock',
#    'Thunder Wave',
#    'Thunder Shock',
#    'Cotton Spore',
#    'Charge',
#    'Take Down',
#    'Electro Ball',
#    'Confuse Ray',
#    'Thunder Punch',
#    'Power Gem',
#    'Discharge',
#    'Signal Beam',
#    'Electro Ball',
#    'Cotton Guard',
#    'Discharge',
#    'Signal Beam',
#    'Light Screen',
#    'Power Gem',
#    'Thunder',
#    'Dragon Pulse',
#    'After You',
#    'Agility',
#    'Body Slam',
#    'Charge',
#    'Eerie Impulse',
#    'Electric Terrain',
#    'Flatter',
#    'Iron Tail',
#    'Odor Sleuth',
#    'Reflect',
#    'Safeguard',
#    'Sand Attack',
#    'Screech',
#    'Take Down',
#    'Thunderbolt',
#    'After You',
#    'Body Slam',
#    'Counter',
#    'Defense Curl',
#    "Double'Edge",
#    'Dragon Pulse',
#    'Dynamic Punch',
#    'Electroweb',
#    'Endure',
#    'Fire Punch',
#    'Focus Punch',
#    'Headbutt',
#    'Heal Bell',
#    'Iron Tail',
#    'Magnet Rise',
#    'Mega Kick',
#    'Mega Punch',
#    'Mimic',
#    'Outrage',
#    'Seismic Toss',
#    'Shock Wave',
#    'Signal Beam',
#    'Sleep Talk',
#    'Snore',
#    'Substitute',
#    'Swagger',
#    'Swift',
#    'Thunder Punch',
#    'Thunder Wave',
#    'Thunderbolt',
#    'Focus Punch',
#    'Dynamic Punch',
#    'Headbutt',
#    'Curse',
#    'Toxic',
#    'Zap Cannon',
#    'Rock Smash',
#    'Hidden Power',
#    'Snore',
#    'Hyper Beam',
#    'Light Screen',
#    'Protect',
#    'Rain Dance',
#    'Safeguard',
#    'Endure',
#    'Frustration',
#    'Iron Tail',
#    'Thunderbolt',
#    'Thunder',
#    'Return',
#    'Brick Break',
#    'Double Team',
#    'Shock Wave',
#    'Facade',
#    'Secret Power',
#    'Swagger',
#    'Sleep Talk',
#    'Swift',
#    'Defense Curl',
#    'Thunder Punch',
#    'Rest',
#    'Attract',
#    'Round',
#    'Echoed Voice',
#    'Fire Punch',
#    'Focus Blast',
#    'Fling',
#    'Charge Beam',
#    'Brutal Swing',
#    'Endure',
#    'Giga Impact',
#    'Flash',
#    'Volt Switch',
#    'Thunder Wave',
#    'Bulldoze',
#    'Captivate',
#    'Sleep Talk',
#    'Natural Gift',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Wild Charge',
#    'Secret Power',
#    'Rock Smash',
#    "Power'Up Punch",
#    'Confide',
#    'Strength',
#    'Flash',
#    'Rock Smash',
#    'Rock Climb']],
#  'anorith': [['Bug', 'Rock'],
#   ['Battle Armor', 'Swift Swim'],
#   [45, 95, 50, 40, 50, 75],
#   ['Scratch',
#    'Harden',
#    'Mud Sport',
#    'Water Gun',
#    'Fury Cutter',
#    'Smack Down',
#    'Metal Claw',
#    'Protect',
#    'Ancient Power',
#    'Fury Cutter',
#    'Bug Bite',
#    'Brine',
#    'Slash',
#    'Crush Claw',
#    "X'Scissor",
#    'Protect',
#    'Rock Blast',
#    'Crush Claw',
#    "X'Scissor",
#    'Aqua Jet',
#    'Cross Poison',
#    'Curse',
#    'Iron Defense',
#    'Knock Off',
#    'Rapid Spin',
#    'Rock Slide',
#    'Sand Attack',
#    'Screech',
#    'Swords Dance',
#    'Water Pulse',
#    'Ancient Power',
#    'Body Slam',
#    'Bug Bite',
#    "Double'Edge",
#    'Earth Power',
#    'Endure',
#    'Fury Cutter',
#    'Headbutt',
#    'Iron Defense',
#    'Knock Off',
#    'Mimic',
#    "Mud'Slap",
#    'Rock Slide',
#    'Sleep Talk',
#    'Snore',
#    'Stealth Rock',
#    'String Shot',
#    'Substitute',
#    'Swagger',
#    'Swords Dance',
#    'Water Pulse',
#    'Water Pulse',
#    'Hone Claws',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Protect',
#    'Frustration',
#    'Smack Down',
#    'Return',
#    'Dig',
#    'Brick Break',
#    'Double Team',
#    'Sandstorm',
#    'Rock Tomb',
#    'Aerial Ace',
#    'Facade',
#    'Secret Power',
#    'Rest',
#    'Attract',
#    'Round',
#    'False Swipe',
#    'Endure',
#    'Rock Polish',
#    'Swords Dance',
#    'Struggle Bug',
#    'Stealth Rock',
#    'Captivate',
#    'Rock Slide',
#    "X'Scissor",
# ...
#    'Thief',
#    'Round',
#    'Focus Blast',
#    'False Swipe',
#    'Fling',
#    'Incinerate',
#    'Endure',
#    'Embargo',
#    'Shadow Claw',
#    'Payback',
#    'Retaliate',
#    'Swords Dance',
#    'Captivate',
#    'Rock Slide',
#    "X'Scissor",
#    'Work Up',
#    'Sleep Talk',
#    'Natural Gift',
#    'Poison Jab',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    "Power'Up Punch",
#    'Confide',
#    'Strength',
#    'Rock Smash',
#    'Rock Climb']],
#  'zapdos': [['Electric', 'Flying'],
#   ['Pressure', 'Static'],
#   [90, 90, 85, 125, 90, 100],
#   ['Peck',
#    'Thunder Shock',
#    'Roost',
#    'Zap Cannon',
#    'Drill Peck',
#    'Thunder',
#    'Peck',
#    'Thunder Shock',
#    'Thunder Wave',
#    'Agility',
#    'Detect',
#    'Drill Peck',
#    'Pluck',
#    'Ancient Power',
#    'Charge',
#    'Agility',
#    'Discharge',
#    'Roost',
#    'Rain Dance',
#    'Light Screen',
#    'Drill Peck',
#    'Thunder',
#    'Roost',
#    'Magnetic Flux',
#    'Rain Dance',
#    'Zap Cannon',
#    'Air Cutter',
#    'Ancient Power',
#    "Double'Edge",
#    'Endure',
#    'Heat Wave',
#    'Mimic',
#    "Mud'Slap",
#    'Ominous Wind',
#    'Roost',
#    'Shock Wave',
#    'Signal Beam',
#    'Sky Attack',
#    'Sleep Talk',
#    'Snore',
#    'Substitute',
#    'Swagger',
#    'Swift',
#    'Tailwind',
#    'Thunder Wave',
#    'Thunderbolt',
#    'Twister',
#    'Curse',
#    'Roar',
#    'Razor Wind',
#    'Whirlwind',
#    'Toxic',
#    'Take Down',
#    "Double'Edge",
#    'Zap Cannon',
#    'Rock Smash',
#    'Hidden Power',
#    'Sunny Day',
#    'Snore',
#    'Hyper Beam',
#    'Rage',
#    'Light Screen',
#    'Protect',
#    'Rain Dance',
#    'Endure',
#    'Roost',
#    'Frustration',
#    'Thunderbolt',
#    'Thunder',
#    'Mimic',
#    'Return',
#    "Mud'Slap",
#    'Double Team',
#    'Shock Wave',
#    'Swagger',
#    'Sleep Talk',
#    'Sandstorm',
#    'Aerial Ace',
#    'Facade',
#    'Secret Power',
#    'Reflect',
#    'Bide',
#    'Swift',
#    'Detect',
#    'Sky Attack',
#    'Rest',
#    'Round',
#    'Steel Wing',
#    'Roost',
#    'Charge Beam',
#    'Sky Drop',
#    'Endure',
#    'Giga Impact',
#    'Flash',
#    'Volt Switch',
#    'Thunder Wave',
#    'Sleep Talk',
#    'Natural Gift',
#    'Fly',
#    'Swagger',
#    'Sleep Talk',
#    'Pluck',
#    "U'turn",
#    'Substitute',
#    'Wild Charge',
#    'Secret Power',
#    'Rock Smash',
#    'Confide',
#    'Fly',
#    'Defog',
#    'Flash',
#    'Rock Smash']],
#  'zebstrika': [['Electric'],
#   ['Lightning Rod', 'Motor Drive', 'Sap Sipper'],
#   [75, 100, 63, 80, 63, 116],
#   ['Ion Deluge',
#    'Quick Attack',
#    'Tail Whip',
#    'Charge',
#    'Thunder Wave',
#    'Tail Whip',
#    'Charge',
#    'Shock Wave',
#    'Thunder Wave',
#    'Flame Charge',
#    'Pursuit',
#    'Spark',
#    'Stomp',
#    'Discharge',
#    'Agility',
#    'Wild Charge',
#    'Thrash',
#    'Ion Deluge',
#    'Double Kick',
#    "Double'Edge",
#    'Endure',
#    'Feint',
#    'Me First',
#    'Rage',
#    'Sand Attack',
#    'Screech',
#    'Shock Wave',
#    'Snatch',
#    'Take Down',
#    'Bounce',
#    'Magnet Rise',
#    'Shock Wave',
#    'Signal Beam',
#    'Sleep Talk',
#    'Snatch',
#    'Snore',
#    'Toxic',
#    'Hidden Power',
#    'Hyper Beam',
#    'Light Screen',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Thunderbolt',
#    'Thunder',
#    'Return',
#    'Double Team',
#    'Facade',
#    'Flame Charge',
#    'Rest',
#    'Attract',
#    'Round',
#    'Overheat',
#    'Charge Beam',
#    'Giga Impact',
#    'Flash',
#    'Volt Switch',
#    'Thunder Wave',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Wild Charge',
#    'Secret Power',
#    'Rock Smash',
#    'Confide',
#    'Rock Smash']],
#  'zekrom': [['Dragon', 'Electric'],
#   ['Teravolt'],
#   [100, 150, 120, 120, 100, 90],
#   ['Thunder Fang',
#    'Dragon Rage',
#    'Imprison',
#    'Ancient Power',
#    'Thunderbolt',
#    'Dragon Breath',
#    'Slash',
#    'Zen Headbutt',
#    'Fusion Bolt',
#    'Dragon Claw',
#    'Noble Roar',
#    'Imprison',
#    'Crunch',
#    'Thunder',
#    'Outrage',
#    'Hyper Voice',
#    'Bolt Strike',
#    'Draco Meteor',
#    'Dragon Pulse',
#    'Earth Power',
#    'Hyper Voice',
#    'Magnet Rise',
#    'Outrage',
#    'Roost',
#    'Shock Wave',
#    'Signal Beam',
#    'Sleep Talk',
#    'Snore',
#    'Tailwind',
#    'Thunder Punch',
#    'Zen Headbutt',
#    'Hone Claws',
#    'Dragon Claw',
#    'Toxic',
#    'Hidden Power',
#    'Hyper Beam',
#    'Light Screen',
#    'Protect',
#    'Rain Dance',
#    'Roost',
#    'Safeguard',
#    'Frustration',
#    'Thunderbolt',
#    'Thunder',
#    'Return',
#    'Psychic',
#    'Shadow Ball',
#    'Double Team',
#    'Reflect',
#    'Rock Tomb',
#    'Facade',
#    'Rest',
#    'Round',
#    'Echoed Voice',
#    'Steel Wing',
#    'Focus Blast',
#    'Fling',
#    'Charge Beam',
#    'Brutal Swing',
#    'Shadow Claw',
#    'Payback',
#    'Giga Impact',
#    'Flash',
#    'Stone Edge',
#    'Volt Switch',
#    'Thunder Wave',
#    'Fly',
#    'Rock Slide',
#    'Dragon Tail',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Flash Cannon',
#    'Wild Charge',
#    'Secret Power',
#    'Rock Smash',
#    'Confide',
#    'Cut',
#    'Fly',
#    'Strength',
#    'Rock Smash']],
#  'zeraora': [['Electric'],
#   ['Volt Absorb'],
#   [88, 112, 75, 102, 80, 143],
#   ['Scratch',
#    'Spark',
#    'Hone Claws',
#    'Quick Attack',
#    'Fury Swipes',
#    'Volt Switch',
#    'Snarl',
#    'Fake Out',
#    'Charge',
#    'Thunder Punch',
#    'Slash',
#    'Wild Charge',
#    'Quick Guard',
#    'Plasma Fists',
#    'Close Combat',
#    'Discharge',
#    'Work Up',
#    'Calm Mind',
#    'Toxic',
#    'Bulk Up',
#    'Hidden Power',
#    'Taunt',
#    'Protect',
#    'Frustration',
#    'Thunderbolt',
#    'Thunder',
#    'Return',
#    'Brick Break',
#    'Double Team',
#    'Aerial Ace',
#    'Facade',
#    'Rest',
#    'Low Sweep',
#    'Round',
#    'Echoed Voice',
#    'Focus Blast',
#    'False Swipe',
#    'Fling',
#    'Brutal Swing',
#    'Acrobatics',
#    'Giga Impact',
#    'Volt Switch',
#    'Thunder Wave',
#    'Grass Knot',
#    'Sleep Talk',
#    'Substitute',
#    'Wild Charge',
#    'Snarl',
#    'Confide']],
#  'zigzagoon': [['Normal'],
#   ['Gluttony', 'Pickup', 'Quick Feet'],
#   [38, 30, 41, 30, 41, 60],
#   ['Tackle',
#    'Growl',
#    'Tackle',
#    'Tail Whip',
#    'Sand Attack',
#    'Headbutt',
#    "Baby'Doll Eyes",
#    'Odor Sleuth',
#    'Mud Sport',
#    'Pin Missile',
#    'Covet',
#    'Bestow',
#    'Flail',
#    'Take Down',
#    'Sand Attack',
#    'Odor Sleuth',
#    'Mud Sport',
#    'Pin Missile',
#    'Covet',
#    'Bestow',
#    'Flail',
#    'Rest',
#    'Belly Drum',
#    'Fling',
#    'Charm',
#    'Extreme Speed',
#    'Helping Hand',
#    "Mud'Slap",
#    'Pursuit',
#    'Rock Climb',
#    'Simple Beam',
#    'Sleep Talk',
#    'Substitute',
#    'Tickle',
#    'Trick',
#    'Body Slam',
#    'Covet',
#    'Defense Curl',
#    "Double'Edge",
#    'Endure',
#    'Fury Cutter',
#    'Gunk Shot',
#    'Headbutt',
#    'Helping Hand',
#    'Hyper Voice',
#    'Icy Wind',
#    'Iron Tail',
#    'Last Resort',
#    'Mimic',
#    "Mud'Slap",
#    'Rollout',
#    'Seed Bomb',
#    'Shock Wave',
#    'Sleep Talk',
#    'Snore',
#    'Substitute',
#    'Super Fang',
#    'Swagger',
#    'Swift',
#    'Thunder Wave',
#    'Trick',
#    'Water Pulse',
#    'Water Pulse',
#    'Work Up',
#    'Hone Claws',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Ice Beam',
#    'Blizzard',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Iron Tail',
#    'Thunderbolt',
#    'Thunder',
#    'Return',
#    'Dig',
#    'Shadow Ball',
#    'Double Team',
#    'Shock Wave',
#    'Facade',
#    'Secret Power',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Round',
#    'Echoed Voice',
#    'Fling',
#    'Charge Beam',
#    'Retaliate',
#    'Endure',
#    'Thunder Wave',
#    'Work Up',
#    'Captivate',
#    'Sleep Talk',
#    'Natural Gift',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Surf',
#    'Secret Power',
#    'Rock Smash',
#    'Confide',
#    'Cut',
#    'Surf',
#    'Whirlpool',
#    'Rock Smash']],
#  'zoroark': [['Dark'],
#   ['Illusion'],
#   [60, 105, 60, 120, 60, 105],
#   ['Night Daze',
#    'Imprison',
#    "U'turn",
#    'Scratch',
#    'Leer',
#    'Pursuit',
#    'Night Slash',
#    'Night Slash',
#    'Night Daze',
#    'Imprison',
#    "U'turn",
#    'Scratch',
#    'Leer',
#    'Pursuit',
#    'Hone Claws',
#    'Pursuit',
#    'Hone Claws',
#    'Fury Swipes',
#    'Feint Attack',
#    'Scary Face',
#    'Taunt',
#    'Foul Play',
#    'Night Slash',
#    'Torment',
#    'Agility',
#    'Embargo',
#    'Punishment',
#    'Nasty Plot',
#    'Imprison',
#    'Night Daze',
#    'Fake Tears',
#    'Captivate',
#    'Copycat',
#    'Counter',
#    'Dark Pulse',
#    'Detect',
#    'Extrasensory',
#    'Memento',
#    'Snatch',
#    'Sucker Punch',
#    'Bounce',
#    'Covet',
#    'Dark Pulse',
#    'Foul Play',
#    'Hyper Voice',
#    'Knock Off',
#    'Low Kick',
#    'Sleep Talk',
#    'Snatch',
#    'Snore',
#    'Spite',
#    'Trick',
#    'Uproar',
#    'Hone Claws',
#    'Calm Mind',
#    'Roar',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Taunt',
#    'Hyper Beam',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Return',
#    'Dig',
#    'Shadow Ball',
#    'Double Team',
#    'Flamethrower',
#    'Aerial Ace',
#    'Torment',
#    'Facade',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Low Sweep',
#    'Round',
#    'Focus Blast',
#    'Fling',
#    'Incinerate',
#    'Embargo',
#    'Shadow Claw',
#    'Payback',
#    'Retaliate',
#    'Giga Impact',
#    'Swords Dance',
#    'Psych Up',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    "U'turn",
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    'Snarl',
#    'Dark Pulse',
#    'Confide',
#    'Cut',
#    'Rock Smash']],
#  'zorua': [['Dark'],
#   ['Illusion'],
#   [40, 65, 40, 80, 40, 65],
#   ['Scratch',
#    'Leer',
#    'Pursuit',
#    'Fake Tears',
#    'Fury Swipes',
#    'Feint Attack',
#    'Scary Face',
#    'Taunt',
#    'Foul Play',
#    'Torment',
#    'Agility',
#    'Embargo',
#    'Punishment',
#    'Nasty Plot',
#    'Imprison',
#    'Night Daze',
#    'Captivate',
#    'Copycat',
#    'Counter',
#    'Dark Pulse',
#    'Detect',
#    'Extrasensory',
#    'Memento',
#    'Snatch',
#    'Sucker Punch',
#    'Bounce',
#    'Covet',
#    'Dark Pulse',
#    'Foul Play',
#    'Hyper Voice',
#    'Knock Off',
#    'Sleep Talk',
#    'Snatch',
#    'Snore',
#    'Spite',
#    'Trick',
#    'Uproar',
#    'Hone Claws',
#    'Calm Mind',
#    'Roar',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Taunt',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Return',
#    'Dig',
#    'Shadow Ball',
#    'Double Team',
#    'Aerial Ace',
#    'Torment',
#    'Facade',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Round',
#    'Fling',
#    'Incinerate',
#    'Embargo',
#    'Payback',
#    'Retaliate',
#    'Swords Dance',
#    'Psych Up',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    "U'turn",
#    'Substitute',
#    'Secret Power',
#    'Snarl',
#    'Dark Pulse',
#    'Confide',
#    'Cut']],
#  'zubat': [['Flying', 'Poison'],
#   ['Infiltrator', 'Inner Focus'],
#   [40, 45, 35, 30, 40, 55],
#   ['Absorb',
#    'Leech Life',
#    'Supersonic',
#    'Astonish',
#    'Supersonic',
#    'Bite',
#    'Wing Attack',
#    'Confuse Ray',
#    'Wing Attack',
#    'Air Cutter',
#    'Swift',
#    'Air Cutter',
#    'Poison Fang',
#    'Mean Look',
#    'Poison Fang',
#    'Leech Life',
#    'Acrobatics',
#    'Haze',
#    'Venoshock',
#    'Air Slash',
#    'Quick Guard',
#    'Mean Look',
#    'Poison Fang',
#    'Haze',
#    'Air Slash',
#    'Brave Bird',
#    'Curse',
#    'Defog',
#    'Feint Attack',
#    'Giga Drain',
#    'Gust',
#    'Hypnosis',
#    'Nasty Plot',
#    'Pursuit',
#    'Quick Attack',
#    'Steel Wing',
#    'Venom Drench',
#    'Whirlwind',
#    'Zen Headbutt',
#    'Air Cutter',
#    "Double'Edge",
#    'Endure',
#    'Giga Drain',
#    'Heat Wave',
#    'Mimic',
#    'Ominous Wind',
#    'Roost',
#    'Sleep Talk',
#    'Snatch',
#    'Snore',
#    'Substitute',
#    'Super Fang',
#    'Swagger',
#    'Swift',
#    'Tailwind',
#    'Twister',
#    'Uproar',
#    'Zen Headbutt',
#    'Curse',
#    'Razor Wind',
#    'Whirlwind',
#    'Toxic',
#    'Venoshock',
#    'Take Down',
#    'Hidden Power',
#    'Sunny Day',
#    'Snore',
#    'Taunt',
#    "Double'Edge",
#    'Rage',
#    'Mega Drain',
#    'Mimic',
#    'Protect',
#    'Rain Dance',
#    'Roost',
#    'Giga Drain',
#    'Endure',
#    'Frustration',
#    'Return',
#    'Leech Life',
#    'Shadow Ball',
#    'Double Team',
#    'Sludge Bomb',
#    'Aerial Ace',
#    'Torment',
#    'Facade',
#    'Secret Power',
#    'Swagger',
#    'Sleep Talk',
#    'Bide',
#    'Swift',
#    'Detect',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Round',
#    'Steel Wing',
#    'Snatch',
#    'Acrobatics',
#    'Roost',
#    'Endure',
#    'Payback',
#    'Captivate',
#    'Sleep Talk',
#    'Natural Gift',
#    'Fly',
#    'Swagger',
#    'Sleep Talk',
#    'Pluck',
#    "U'turn",
#    'Substitute',
#    'Secret Power',
#    'Confide',
#    'Fly',
#    'Defog']],
#  'zweilous': [['Dark', 'Dragon'],
#   ['Hustle'],
#   [72, 85, 70, 65, 70, 58],
#   ['Double Hit',
#    'Dragon Rage',
#    'Focus Energy',
#    'Bite',
#    'Focus Energy',
#    'Bite',
#    'Headbutt',
#    'Dragon Breath',
#    'Roar',
#    'Crunch',
#    'Slam',
#    'Dragon Pulse',
#    'Work Up',
#    'Dragon Rush',
#    'Body Slam',
#    'Scary Face',
#    'Hyper Voice',
#    'Outrage',
#    'Tackle',
#    'Assurance',
#    'Astonish',
#    'Belch',
#    'Dark Pulse',
#    'Double Hit',
#    'Earth Power',
#    'Fire Fang',
#    'Head Smash',
#    'Ice Fang',
#    'Screech',
#    'Thunder Fang',
#    'Aqua Tail',
#    'Dark Pulse',
#    'Draco Meteor',
#    'Dragon Pulse',
#    'Earth Power',
#    'Hyper Voice',
#    'Outrage',
#    'Shock Wave',
#    'Sleep Talk',
#    'Snore',
#    'Spite',
#    'Superpower',
#    'Uproar',
#    'Zen Headbutt',
#    'Work Up',
#    'Roar',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Taunt',
#    'Protect',
#    'Rain Dance',
#    'Frustration',
#    'Return',
#    'Double Team',
#    'Torment',
#    'Facade',
#    'Rest',
#    'Attract',
#    'Thief',
#    'Round',
#    'Incinerate',
#    'Thunder Wave',
#    'Psych Up',
#    'Dragon Tail',
#    'Work Up',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    'Dark Pulse',
#    'Confide',
#    'Strength',
#    'Rock Smash']],
#  'zygarde': [['Dragon', 'Ground'],
#   ['Aura Break', 'Power Construct'],
#   [108, 100, 121, 81, 95, 95],
#   ['Glare',
#    'Bulldoze',
#    'Dragon Breath',
#    'Bite',
#    'Safeguard',
#    'Dig',
#    'Bind',
#    "Land's Wrath",
#    'Sandstorm',
#    'Haze',
#    'Crunch',
#    'Earthquake',
#    'Camouflage',
#    'Dragon Pulse',
#    'Dragon Dance',
#    'Coil',
#    'Extreme Speed',
#    'Outrage',
#    'Bind',
#    'Block',
#    'Draco Meteor',
#    'Dragon Pulse',
#    'Earth Power',
#    'Hyper Voice',
#    'Iron Tail',
#    'Outrage',
#    'Pain Split',
#    'Shock Wave',
#    'Snore',
#    'Spite',
#    'Superpower',
#    'Zen Headbutt',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Hyper Beam',
#    'Protect',
#    'Safeguard',
#    'Frustration',
#    'Earthquake',
#    'Return',
#    'Dig',
#    'Brick Break',
#    'Double Team',
#    'Sludge Wave',
#    'Sandstorm',
#    'Facade',
#    'Rest',
#    'Round',
#    'Focus Blast',
#    'Giga Impact',
#    'Stone Edge',
#    'Bulldoze',
#    'Rock Slide',
#    'Dragon Tail',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Secret Power',
#    'Rock Smash',
#    'Confide',
#    'Strength',
#    'Rock Smash']],
#  'zygarde-10%': [['Dragon', 'Ground'],
#   ['Aura Break', 'Power Construct'],
#   [54, 100, 71, 61, 85, 115],
#   ['Glare',
#    'Bulldoze',
#    'Dragon Breath',
#    'Bite',
#    'Safeguard',
#    'Dig',
#    'Bind',
#    "Land's Wrath",
#    'Sandstorm',
#    'Haze',
#    'Crunch',
#    'Earthquake',
#    'Camouflage',
#    'Dragon Pulse',
#    'Coil',
#    'Outrage',
#    'Draco Meteor',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Hyper Beam',
#    'Protect',
#    'Safeguard',
#    'Frustration',
#    'Earthquake',
#    'Return',
#    'Brick Break',
#    'Double Team',
#    'Sludge Wave',
#    'Sandstorm',
#    'Facade',
#    'Rest',
#    'Round',
#    'Focus Blast',
#    'Giga Impact',
#    'Stone Edge',
#    'Bulldoze',
#    'Rock Slide',
#    'Dragon Tail',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Confide']],
#  'zygarde-complete': [['Dragon', 'Ground'],
#   ['Power Construct'],
#   [216, 100, 121, 91, 95, 85],
#   ['Glare',
#    'Bulldoze',
#    'Dragon Breath',
#    'Bite',
#    'Safeguard',
#    'Dig',
#    'Bind',
#    "Land's Wrath",
#    'Sandstorm',
#    'Haze',
#    'Crunch',
#    'Earthquake',
#    'Camouflage',
#    'Dragon Pulse',
#    'Coil',
#    'Outrage',
#    'Draco Meteor',
#    'Toxic',
#    'Hidden Power',
#    'Sunny Day',
#    'Hyper Beam',
#    'Protect',
#    'Safeguard',
#    'Frustration',
#    'Earthquake',
#    'Return',
#    'Brick Break',
#    'Double Team',
#    'Sludge Wave',
#    'Sandstorm',
#    'Facade',
#    'Rest',
#    'Round',
#    'Focus Blast',
#    'Giga Impact',
#    'Stone Edge',
#    'Bulldoze',
#    'Rock Slide',
#    'Dragon Tail',
#    'Grass Knot',
#    'Swagger',
#    'Sleep Talk',
#    'Substitute',
#    'Confide']]}
